# %% [markdown]
# ### Item-base Collaborative Filtering - Model & Index
# This notebook demonstrates how to build a Item-based collaborative filtering model using Yelp dataset. You can adjust the model to add more features or change the hyperparameters to improve the model performance. The index is built and stored in the `yelp_ItemCF.db` file.
#
# #### Pre-requisites
# 1. Have the processed Yelp dataset in the `../../data/processed_data/yelp_data` folder.
# 2. Have the virtual environment setup and used for the notebook.
#
# #### Move to Production
# 1. Copy the `yelp_ItemCF.db` file to the `../../data/processed_data` folder.
# 2. Update the `ItemCF.py` file in the `../backend/models` folder if there is changes in retrieval process.

# %% [markdown]
# #### adding clustering to the pipeline
# considering the number of review of each user, determine the median of review count
# - for user review count larger than the median, index only using individual interaction
# - for user review count less than the median, consider the other user in the same cluster

# %%
# import the python file from ../utilities.py
import sys
sys.path.append('../')
from utilities import *

from scipy.sparse import csr_matrix
from sparse_dot_topn import sp_matmul_topn
from sklearn.model_selection import train_test_split
import time

# %%
# Define the database folder path and file names
db_folder = '../../data/processed_data/yelp_data/'
data_files = ['business', 'categories', 'review']

# Load data into a dictionary
yelp_data = load_data_from_db(db_folder, data_files)

# Check loaded data
for table, df in yelp_data.items():
    print(f"Loaded {len(df)} rows from {table} table.")
    
df_review = yelp_data["review"]
df_business = yelp_data["business"]
# Out:
# Loaded 78059 rows from business table.
# Loaded 360656 rows from categories table.
# Loaded 980418 rows from review table.

# %%
# LAMBDA = 0.0000000005
# LAMBDA = 0.00000000005
LAMBDA = 0.0000000001
current_timestamp = int(time.time())

df_review['timestamp'] = pd.to_datetime(df_review['date']).astype(int) // 10**9
df_review['timestamp'] = np.exp(-LAMBDA * (current_timestamp - df_review["timestamp"]))
df_review['stars'] = df_review['timestamp'] * df_review['stars']

# %%
# per user
review_counts = df_review.groupby('user_id').size()
median_review_count = np.median(review_counts)
# find the quartiles
q75 = np.percentile(review_counts, 75)
q90 = np.percentile(review_counts, 90)
q95 = np.percentile(review_counts, 95)
q100 = np.percentile(review_counts, 100)
print(f"Median number of reviews per user: {median_review_count}")
print(f"75th percentile of reviews per user: {q75}")
print(f"90th percentile of reviews per user: {q90}")
print(f"95th percentile of reviews per user: {q95}")
print(f"100th percentile of reviews per user: {q100}")
# Out:
# Median number of reviews per user: 2.0
# 75th percentile of reviews per user: 5.0
# 90th percentile of reviews per user: 13.0
# 95th percentile of reviews per user: 23.0
# 100th percentile of reviews per user: 953.0

# %%
df_cluster = pd.read_excel("../data_processing/clustered_users.xlsx")

# %%
df_cluster['cluster'].describe()
# Out:
# count    99812.000000
# mean      1207.753897
# std        670.185910
# min          0.000000
# 25%        666.000000
# 50%       1156.000000
# 75%       1733.000000
# max       2502.000000
# Name: cluster, dtype: float64

# %%
user_cluster = df_cluster.set_index('user_id')['cluster'].to_dict()
df_review['cluster'] = df_review['user_id'].map(user_cluster)
# cluster_items = df_review.groupby('cluster')['business_id'].apply(set).to_dict()

# %%
# Calculate the number of reviews per cluster
cluster_review_counts = df_review.groupby('cluster').size()

# Dictionary to store the timestamp threshold for recent reviews in each cluster
cluster_recent_thresholds = {}

# Determine the threshold timestamp for each cluster
for cluster, count in cluster_review_counts.items():
    # Sort reviews by timestamp descending (higher values = more recent)
    cluster_reviews = df_review[df_review['cluster'] == cluster].sort_values(by='timestamp', ascending=False)
    # Find the index that marks the top one-fifth of reviews
    threshold_index = int(count / 5)
    # Get the timestamp at this index (if cluster has fewer than 3 reviews, take all)
    threshold_timestamp = cluster_reviews.iloc[min(threshold_index, len(cluster_reviews) - 1)]['timestamp']
    cluster_recent_thresholds[cluster] = threshold_timestamp

# Filter df_review to keep only recent reviews
df_recent_reviews = df_review[df_review.apply(
    lambda row: row['timestamp'] >= cluster_recent_thresholds.get(row['cluster'], 0), axis=1
)]

# %%
df_recent_reviews['cluster'] = df_recent_reviews['user_id'].map(user_cluster)
# cluster_items = df_recent_reviews.groupby('cluster')[['business_id', 'stars']].apply(
#     lambda x: x.reset_index(drop=True)
# ).to_dict()
# Out:
# C:\Users\cathy\AppData\Local\Temp\ipykernel_27948\826690988.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_recent_reviews['cluster'] = df_recent_reviews['user_id'].map(user_cluster)

# %%
cluster_items = df_recent_reviews.groupby('cluster')['business_id'].apply(set).to_dict()

# %%
cluster_items
# Out:
# {0.0: {'0aktKA1TIWpjXSz0_0qOkg',
#   '2xxkaRy7rP5EUyjFt2J5kA',
#   'GehOuYICXSNZlxkC44R9jQ',
#   'Ht40JGyv37VVrEGJp2s3mg',
#   'IqyHN1g7PO179qtqDf01tw',
#   'RdsPXJj5ta_ed12At_sR3w',
#   'Z1ntn-P9HzXQ-6QzU8PO9A',
#   'qswhfcTS2jZozSzswsNSrA'},
#  1.0: {'2qVZiMB22YPC2HCM62Gnbw',
#   'BcxCBbj7MeLBsyPzuHgklw',
#   'EtbukcoR6QW6_5fEeFcVoQ',
#   'KSYONgGtrK0nKXfroB-bwg',
#   'MCQJc2X_NE6vbfwJdRZl4w',
#   'NvMYRJ_wPJmt4FFsEF7O0A',
#   'mE16tq2q9kIAeI1wnPkKXQ'},
#  2.0: {'R3dw5YDLYSNpUn_u994rhQ', 'heUFH7q9_syl4a5QSqy8rA'},
#  3.0: {'0aJXMRNfbKqiU99t-iOk8g',
#   '50mfwRz6WA20SS3E080uTg',
#   '6eXzDaL0NA0RvASXpvYt8Q',
#   'A3VrcPqMLUfcmTbkDXTSaQ',
#   'CS3dJ8m5rVd6u6bkqyt0lQ',
#   'DO_op-iq4qoaOBEhJH6EdQ',
#   'IJ5N0TNgDDFP0UauRmepDg',
#   'JfThFucRnJdJxQtS6gHfWw',
#   'KaTElVme7lVLlULON3EJTw',
#   'Q7aDbce5rFbH1Cgcyry9zQ',
#   'TSnzP2pDd403xVXSNXuFFA',
#   'X8P-rVqwMB-QI-Atjpe76w',
#   'bISwIzk6cMQtTf3QSlXi5Q',
#   'bxyT4iNcdnfHvPyc6NTBIw',
#   'e4InIycH2PAJWccBBj0tAA',
#   'gf0JIIduGDyy6V0vhPjCtA',
#   'hlq5APjsJb7mwmDql0tIGw',
#   'jLTNVE_86BXEjYO97JTCWA',
#   'rQ1t0zD_TBTqCF06By_UgA',
#   'sTuDLAMOxhhWQAsKsbGioQ',
#   'vI1BG1dJx8DPm4a1ljkfMw',
#   'y-g8sgT7WkN16BBe9Vj41g',
#   'zV6r2t0IN8g-rRFGtvly_Q'},
#  4.0: {'-rKaikuKBl1BwDPNJOn_qA',
#   '1WwigTZ4jkb_9LwrthmOqg',
#   '1WyB_NW1N2RT8Fpnky-BeQ',
#   '3TmTAM1kXxFnuLgAv3cdrg',
#   '5K6ljsbWjGzK7NcVMV41Nw',
#   '7Hw3PZ8DduMVbmtZ0t9qwg',
#   'C96zju-kAJa3birAHA6GQg',
#   'CYwC5OjwCN6ib_AQDxi3Ow',
#   'HSv0Pe45yPAs6PgwlcTPcg',
#   'Ru1wQXYcrt_itF94K9yJpA',
#   'Ta8DsodAtfHHvXguSDM5Xw',
#   'UeemkxzMST9c7rKucGCJmg',
#   'UhvOBTrHfvGJM4_xhFVH6A',
#   'XeogL9kqQxKEO42ZEqMbvg',
#   '_ZOEQFCofLnZVK0smXyeGA',
#   'h0wHeh0hTt6Us4W-1SHQOw'},
#  5.0: {'DQnKn3e_PCa1E0OPcxVsBA',
#   'IQzeJhxS4_m9EofxDVQHaQ',
#   'NXs4byOiMay3DkMLuvgJxw',
#   'QIYVaE6qrgAYHV6aJhqfJQ',
#   'S9ufIJaPSq-Y5bRidcaDWg',
#   'Sr4w6zOQRPFiGILQ7esPHA',
#   'eLjXnfYwkr8zz0VhwMhOGw',
#   'ftvJpV1dX9a_pd0e72nB5g',
#   'jB96BxpnIkcAQ9iF_R75LQ',
#   'lRCA11IAq1VZqKIJCY8VBQ',
#   'tDzG-Kmmuf5v5VkLCd7Yig'},
#  6.0: {'AsPwZ_T0_eJrKbr-hAqqMw',
#   'C32fy017b5exHYo6x4zQfQ',
#   'JJLr9WflS19A0vtuVK4tww',
#   'Kpq3dO74ZCxIHdQU8Yvlgg',
#   'RDChgx8DaaqOnxlpElBsRQ',
#   '_Lh_aMl_J8VHibVIsJLZbw',
#   'fO52yQ7zBh5EQACZQ4ujxA',
#   'hTJ4B-77wfJ6kos6_DQUHA',
#   'i7_3lQzM5SP8Cc2YT-X3BA',
#   'rtcvzasl5T9pVSPsbKU3pw',
#   'wyBSJFFBrzWd6WQGTl_wAA'},
#  7.0: {'02qFLwwFi8T804rHcYh7Zw',
#   '1BuMNzidsGEyvB11sj19Pg',
#   '3TNaIkVUKrHzeeWMo9DMkg',
#   '4-WY7Omp6ibxkdKk3abQ3A',
#   '4lop2hfUIgttXnYtWK-Euw',
#   '5AwQnUJKugSSv_TekCzORg',
#   '5CX7rtnwYnmqFCihOyWivg',
#   '6Elosz30YlUT3PTGF_Kwew',
#   '9u4_k8-XC4RFETCeiQdO8w',
#   'Aw9Tldxcg5ifodzn0R2O6g',
#   'THoNnFJFVzzjz7hyOIQFkQ',
#   'TpUGMw7Lq9p5WT1t2qHD0A',
#   'aJdE0yRIyXOw-QQEfLBCJA',
#   'eFtQDmNER9pRB9YdPxMMXA',
#   'eIKjxqdMduIeIqzPg7yc-Q',
#   'eN-Zrz1orLoqIb7D6mUMbg',
#   'i76ERS3jM111T3VMbi2yrQ',
#   'jNxvJeAUzzpC7zW3UN78HA',
#   'oQ_SoB3-57wqGETW_K6AtQ',
#   'ovUZ8Ff8QRNi0x2xJ1RWWg'},
#  8.0: {'--S43ruInmIsGrnnkmavRw',
#   '06NHXjVHiGKNpZ2XeajVkA',
#   '0RFb4sAljaBV2HeRXee4-A',
#   '3cT6KPlkOQGZv2Lk7p9_1A',
#   '4WdDY97x4GdMYtyk1KQMnw',
#   'CG1Bb2MTraJYTHCPFm72XA',
#   'GoGss2SqsUPwP0xcI9IUuw',
#   'INeL2YsGJRX-QulzFRKKXg',
#   'IcqJQ3DBOGDdz70Q8DTghQ',
#   'SNclIeZ9Zxqigdkiq0hNSg',
#   'UoZg0xZepdMXbK_2dtT2nw',
#   'VaO-VW3e1kARkU9bP1E7Fw',
#   'W9SliuSyX7N0XoiG9UFNdQ',
#   'ZaUVTggOTNXvRbMWvD7kfA',
#   'Zi-F-YvyVOK0k5QD7lrLOg',
#   'aIVk0IEUj7rPaAMeAmBSGg',
#   'bDwAOwlB-HkOqvSfHumfng',
#   'dmylotBWcIExhwyyft5bIw',
#   'eD018QIwrljtaF4Dqe0A6Q',
#   'fLM3emFZM3NjUKysn5_yEw',
#   'rIPy-Q-w4hrvcdSbCakXpg',
#   'zafEaH7VOUkd8-9wFlnlmw'},
#  9.0: {'--S43ruInmIsGrnnkmavRw',
#   '-0__F9fnKt8uioCKztF5Ww',
#   '-UEeCTgxud4OGWshX4x-jw',
#   '-VlBFlHwX-Pt6Xyzs9roGw',
#   '-_DYwksHcLSXEYo_pVVENA',
#   '-vP_oH77aIgqITqWKn9uog',
#   '04l8PYcuYQeEkEhJCbhtOA',
#   '0IZO0wj0XkOJ6hDFgXGzBg',
#   '0JmFfcBbIux_vauRNWzD9Q',
#   '0JtYKzRiG1Rad7nyhObEHQ',
#   '0UJqTczta018RoktahC0jw',
#   '0yEl45kZ8o37lvpkhCBM4w',
#   '1dsXfbB9Kvc06wv65Zbrzw',
#   '2DTkzhmMpv5fIPKheePClA',
#   '2QGyW4T6E_4iSltdx9i2RQ',
#   '3CcQS_pHoq9RPaOWYlo_7Q',
#   '3aCIpZgIeDwB1uQBAaPbKQ',
#   '3fVYGQr_ldW2_1QlXJjpaQ',
#   '3j7HJaFsbSlf5flDJfoyGw',
#   '3n2FIVhxAjG6fjju4wdzXw',
#   '3qEjUW12sH6KOBm86ZDmTA',
#   '3rRESenaBw-AyT0Jt7eJNg',
#   '4EaRjOTNIo-72sQMf-Wykg',
#   '4XDoDb7D8j0WWb8EDC1ljA',
#   '4kwny3ZC2QWyzhWLGhry-A',
#   '4w_TG6uA5bIxnC5tpkOb3g',
#   '4xV3C_5VXQzAAYGIwJ_4dg',
#   '5AOkxsg6UJQ_CoJTMBDUmQ',
#   '5O3vEISAkmh0lnArUBp_Cw',
#   '5bT-bq-u8rEjBopZg4LCeQ',
#   '5qFQhRkKP7xHNoycDu6mOQ',
#   '5uPdoWQNjYkrpRmy9AonSw',
#   '688utk-zc_7eA3HNhccevA',
#   '6_OAIFxSk3YjNdRJv59Saw',
#   '6ixTweh-QM88GDrHTjegGA',
#   '6jKFWxE2fJIhfwbYgwqcfg',
#   '75FY8ZQx5nOWP0VFmNvWfw',
#   '7D5-a53BLau19RpMu-L3zg',
#   '7fuyFmESXQYir9AtweuD8w',
#   '7gtWQMLOEwCxh1I5j6uB4g',
#   '8ASzjS3ITg5bQSyObsCx5w',
#   '8FWAoGPBwRS3I7_FP7u-Mw',
#   '8NyDM-FDoWEEeEG9XUwnbg',
#   '8UPv1p9GW-BiZtQqUt8nOA',
#   '8jwsNjvVNJiYN7AnxHdMLA',
#   '95d60_mjUg2kLy-bhDLC6w',
#   '98mYebjHN_VXZapVm8Nmqg',
#   '9PZxjhTIU7OgPIzuGi89Ew',
#   '9kv9JpLhzkN3UeWZDrsmEA',
#   'A0DYN5wxygYnX_sL3HygvA',
#   'A8ivmB48-sMd4eBwIErs7A',
#   'AWnzFqIrlkLAKTc46_zmEg',
#   'BJauHq_tArHgi0nncImNJg',
#   'BfAYvF-GsCljAFNRmuP3lg',
#   'BjeHLwKOlHyV6DJgmZxAjA',
#   'BuQGsltd3B4L_HRCP2jpTQ',
#   'CG1Bb2MTraJYTHCPFm72XA',
#   'COIL2VeL6MN-5Ou1D1i9bg',
#   'CTAQDdtQbVpGw5FysZ6cEA',
#   'ChlcxTEoWBQJXJ2Xb2vm5g',
#   'D0T1M5BJFWCJ7DAgxZBykA',
#   'DEFte_S3i2EcRLH7XbWQZA',
#   'DOfiulOub9hVPBCtiDl9Fw',
#   'EC20rN7JtmAPIxcw3MTzcQ',
#   'ECOUuwE5H1HHE8xBfNAjFg',
#   'ECg2k3n1y8xZps3szszlwQ',
#   'EME5hqQLjBD7e2cLryupbA',
#   'EYh3aE3mqmQ3k9Laznc58A',
#   'EZtCmVJv_BI5CoyR-TCdVw',
#   'Eb1XmmLWyt_way5NNZ7-Pw',
#   'Edg22x3CZkIv0GUib2oEFA',
#   'El_2Cxuq4hxqrmlg_5nzzA',
#   'F9OFNrITmQ1a9glscJ20ag',
#   'FCCnOgjjvwQJBAy3u2fcLA',
#   'FEXhWNCMkv22qG04E83Qjg',
#   'FSvFk1lWR0YBYP_-L_iLTQ',
#   'FkOTPqfnnKvhk81RZhPy-w',
#   'FkmUQqJCjgAYSlckQL0umw',
#   'FxosV3rl41ZlR724nnrImA',
#   'GBTPC53ZrG1ZBY3DT8Mbcw',
#   'GKwL82D7-xy5HU6OuWyn2A',
#   'GM6j5hDNqra0pVfTcpTMMw',
#   'GSOLNXG5-IPvNj0DPf3kOQ',
#   'H5KRna9A6mDQEJ2ZN0zL6g',
#   'HEf0QXnhxrcIWxRfAbQ2iA',
#   'HUcjSm1Lxdn8zSu-hQ7-sw',
#   'Hh-lUvqYOnf7E6-fqAKzNA',
#   'I0I2mkCOPTYVSLpc8A8VVw',
#   'I3Uy20BKx7G-Fzz6hLIeWg',
#   'ILWv3aMVbZUMjcMSTGgStQ',
#   'Iq7LZi_MCUg8xAfboc_r7g',
#   'JAqY1Pw4wYCv0kkFQAyTRQ',
#   'JHyxZ_rhJ2DziKQ9BDsLtQ',
#   'JpRss-a6Nb1nc3fUvl3MAg',
#   'KLLO4MTEI2mDwdakz51www',
#   'M0YuK7sLLSA3TfBC4UkUzg',
#   'M1hsyjJDdQQeNP164FJ1pA',
#   'MCDKORBcNIjKGF79sXFOcg',
#   'MG7aNGdD-jYNaZtyCgFqKA',
#   'MiTuey9Pdc2haG9KQgmU7Q',
#   'MqFQqNhMRaizyVRwsea6EA',
#   'N4IFNpTn7kKfK9akJkerwQ',
#   'NB5XTBuLVCn7c9Lu5SUqKg',
#   'NHdE_ObFj7OjQBB3jjqBNQ',
#   'NOiW9rx0kwYLCv_YNX20Bg',
#   'NgEy0AX40Yg4Bpon61wbEg',
#   'OINbC0rpDVJ5bfxt3LO9fw',
#   'OIbh0ZOemmphJR4Att3E6A',
#   'ObZu0-S1VAqAuCbAF5AFvw',
#   'OnRVDfcev5GKjRHJbKM_EQ',
#   'P2Lm1g_RztvIaH4daQsXoQ',
#   'PupRtvjjZJcLzIlkMw3hpA',
#   'QA8QLpwf_YT9C2ST5YJ0vw',
#   'QE2KzOMx80dUIkW7NNiH6w',
#   'Qlmusk0BBY0kMOd8Y96H4A',
#   'R2_2-KMIlpQ9besSEnWxfw',
#   'Rx5lfHMWkezmQjCfr2ziAw',
#   'SYCGlb0WFyyVxD2K9Z-YuA',
#   'SeLObMnlgTwz8PoT_gSZ0Q',
#   'SjiRaZoWaDpkCCpq5SsrMw',
#   'Skb9QnlE0wle-0KlCpT5pw',
#   'TNTBObKmICMn13T0pyAGyg',
#   'TUTQeLjq1UbkR5r8mOvMqw',
#   'Tv5gLZyjnMuEpLvdbE5wGw',
#   'TvbJq1a1Xto5w6t4zMUYHQ',
#   'U2fN80Q-QOudDt5V-qjIlw',
#   'UK6T9L11dQMJ3bBsm3v4EA',
#   'UR9dzGGVfcJhHt_mG3bTRA',
#   'UbFkHiEt9S-0mUL3RQ5Ghg',
#   'UnQriKTiNsYnyPE3Rt8lTQ',
#   'UoZg0xZepdMXbK_2dtT2nw',
#   'V1n-wIrt5xtI0VIAxIP5dA',
#   'VLfiukM-1hlx8_1Kd1uGnA',
#   'VQcCL9PiNL_wkGf-uF3fjg',
#   'VaO-VW3e1kARkU9bP1E7Fw',
#   'VlqngN60qoCeOlUvWXD4qg',
#   'W3vh-SwbjqvTWczrDOsKgA',
#   'W4ZEKkva9HpAdZG88juwyQ',
#   'WXgV2lOUgas7DzTLeDau-w',
#   'WrU1ZYN4jlYcL5mvJrQsCQ',
#   'WtVOrfqLXerig9Z7iP-NzA',
#   'Wxcz9GHVfLUhER5FQAEDng',
#   'X7W01ESZV0UybJ859ZnWRQ',
#   'XD6GGQWPvJVfFyiMN2wNXw',
#   'Xh08NmHdB86LexgXrIxr2Q',
#   'XjjgJb0iyG33CQp4ehnRGQ',
#   'XyunkhTKBteNo0Sbap8R3g',
#   'Y1FU2s1OytJGdXksraIGFw',
#   'Y2Pfil51rNvTd_lFHwzb_g',
#   'Y2lE2JWRk4VGq0zUAmigCQ',
#   'YB26JvvGS2LgkxEKOObSAw',
#   'YNjyv0gfOr2g8lbmUpTnKg',
#   'YSyZipJDgS3D_R0wqPqPhQ',
#   'YUtYV7iXqiUX19gFBiy9SQ',
#   'YwezxSSXcrT5GOTI5MddPg',
#   'ZDV6ocQSe6dkMt-u011xcQ',
#   'ZLrqw4KCwKyBlVqycUfNbg',
#   'ZNxFIwgPnmLu6ouQPPpR_Q',
#   'Zi-F-YvyVOK0k5QD7lrLOg',
#   'Zt7SfTU6N9SKDvVvpNpoGg',
#   'Zy5IZ-3C8s4iHw55LPkKVQ',
#   '_393npnr0Dw1aGKy83x_0A',
#   '_C7QiQQc47AOEv4PE3Kong',
#   '_LgI5387qAmMuS8i6h69cg',
#   '_ab50qdWOk0DdB6XOrBitw',
#   '_d4oswY38HTB5UWMMEt_jA',
#   '_dDW5rc7MKCOzhRewe3Kfg',
#   '_n539Sga7PCvHQs--a4qkA',
#   'a1u9Bxrq_fZxl2pgqQUcJA',
#   'aIVk0IEUj7rPaAMeAmBSGg',
#   'aLsbsBbaJzYw3chcdQlCIw',
#   'aPDpK9mHhrabKyspSKME6g',
#   'aYJjJMN8heS2PmkvsQzaZg',
#   'aZ2s_4xvwDCVIvfwI2ctEw',
#   'ac1AeYqs8Z4_e2X5M3if2A',
#   'ap5bxhjMs3f4alh7Zu51nQ',
#   'b0zp6rgcv7ZcjToRoVhcmQ',
#   'b2I07KOWVlCMhJghq6-IqQ',
#   'b3tI8ODMieXSflFHLFA92A',
#   'b9d9X2yhzxSVEbz_JIY_uA',
#   'bYVz2xUxg_SDRwW7h0ewHg',
#   'b_WqANUY0faWZOpMNiBLew',
#   'c-iKAO2GBzSKjm7y1Oljcw',
#   'cARWyMM1xGggmIiRX326IQ',
#   'cTSczU-9-cYUEM2DlNJcQw',
#   'ct-VF8Yqj4GlxEHZ23Arig',
#   'd7W1Fi6uRYUhDT_uW83d7w',
#   'd89jkOMbjpTBerh7miCz2w',
#   'dIQGbalj-3I8vixZ4M149g',
#   'dTWlXxBotTogKu6OddCnyQ',
#   'dU0ZYEZXTtMdDC9XwARtDw',
#   'dclL14pr7OojCOKJ_ZbMbQ',
#   'dz_aIFbATP2PLWQSOBnMfw',
#   'e5fCI12X_GLCST668S4ROA',
#   'ecI3FBTM0f99Fnml3kNKfg',
#   'edJoBsse6nsF0BYh6pATAg',
#   'fla4vQjwBYVD3-AHAGnMFw',
#   'g-YOzV9YIPmo6vZBHQuuUg',
#   'g5ogvPhw3PSobtaZFkdEXg',
#   'gTC8IQ_i8zXytWSly3Ttvg',
#   'gjbmwlYUImb2lQBp5LV3KA',
#   'hBrMezBy-8E3EYy4tCScfQ',
#   'hGsITEITVK7LkZQeNv-Fpw',
#   'hPd6uMCjNglnOwwHpkY5Tg',
#   'h_tRcijFYxrUiZ59FXfBOQ',
#   'hlHkDOaRT1gmqpUi2vqkzQ',
#   'htDRn1cXDyimxz6BJWB3LQ',
#   'htx6Uime2SkiE-zC7hxb-g',
#   'iJ3A49gtUPspc7nd4Ov2HA',
#   'iSRTaT9WngzB8JJ2YKJUig',
#   'iSwT3_vaI-33bENqep_ECQ',
#   'iVegX9epKU8R0eRAEwQ6Yg',
#   'i_BpS8-4ri6Pr-sW0fP0fQ',
#   'i_FWONQD1ZBqrNE2b-M5Ug',
#   'ifC2ha-7HZt4xKUVou6wTw',
#   'ir6unv7MPSxqCr2KXuMeTA',
#   'jQNmnjrNd1tJXOg9bfB5hA',
#   'j_wOxQrfgJKQdL4G5u8_1A',
#   'jrDK6gzJh0VHjttG4SNxZw',
#   'kAOn-rLmNnm0YM9x6mZ_6g',
#   'kGhT5VRj2ZBSdXJl6qkLdw',
#   'kSS2nvAscVe9dHwihJVUiw',
#   'kb1Tf4xwb7CQW5OXf9zwqw',
#   'kk0vWjuy9ixqOI57iwjskQ',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'lTTmtjhLZIj6vWSuIOyxwQ',
#   'ldczA2r_LlKSfbrGxt3ThQ',
#   'lumQFFky9M3na55B4O0S4Q',
#   'mRpk0A4u0hnF0lNe1h4hGg',
#   'mTvb9By6kzoVkPtQbrsUSg',
#   'mXnlC59Wqe_Q8lAxmchBJg',
#   'mq8iNBD77TP6eWfFIQO5rQ',
#   'nrXtCSdfWg0TJ86onEZWkg',
#   'oBNrLz4EDhiscSlbOl8uAw',
#   'oCbJpGl8IkH1WdYa25TDBA',
#   'pym7c6ZFEtmoH16xN2ApBg',
#   'qclZoDz3sjT7v5xOSj5P2Q',
#   'qt_E6txwQ1h62wyv8701UQ',
#   'qvGfM67TXU-akls99x2ibg',
#   'rkZsld6EP8r_iYRba7ug8Q',
#   's4r3OEFu8q1HAB06CnEPCA',
#   'sIfiMNaayTDhoXOKk_-K4A',
#   'sXSUzImYOcRRI3xtG2M85g',
#   'sn4-BbWfsdQ4UVukfRl2Nw',
#   'swVdc9piXvG0AXwL-F0GfQ',
#   't0FzBzAoqVpK5fNIGOPv-g',
#   'tWoJMHMU-KUEeOFAcpENdg',
#   'ta5Oi3sezvn4H299MbtE8Q',
#   'tsx84z4c0B-y6J5fqfvBqg',
#   'u7uFQCoHFtBKCtbWUm6yZw',
#   'ujyjBLOzSXKO3RrbpJ4N4g',
#   'uw5w12snXu-uLtT67Fjkcw',
#   'uyfOQql0ZGMG4WEIwUeeEQ',
#   'vN6v8m4DO45Z4pp8yxxF_w',
#   'vj6AetpADpHOYtMRZsXX3g',
#   'wTCA2ZJsssbOCjG0h0ZiGg',
#   'wYdlP6g2y6gK_RmLrPhsGA',
#   'ww3YJXu5c18aGZXWmm00qg',
#   'xB3MxRBF6l8rd9xxJVnLhw',
#   'xXAWWlpXGlDfgGzy9TTJIw',
#   'xZKhj_0PWf9F0ubRyFG5og',
#   'y-g8sgT7WkN16BBe9Vj41g',
#   'yE6aDcbbK8pmvNroXnQYQA',
#   'yGlPsqK8ck33EgvUINIfvQ',
#   'yS-A-mNVlFf5kbaC028KJw',
#   'yf8a1DOlqoqlKHuLSKEfxg',
#   'yz0KWVamNhqiZGz7XTClzg',
#   'zHoIBH6nIh_Hs8YkSJii5Q',
#   'zI0OdjkdQqD7az8aM6ppdg',
#   'zWfzgYe2nT9mHYm_vl1Ukw',
#   'zurZgdE3W9jJnU6VAgTdSg'},
#  10.0: {'-1XSzguS6XLN-V6MVZMg2A',
#   '-Tskf8WK17rb3ZfeFuRSWA',
#   '3rRESenaBw-AyT0Jt7eJNg',
#   '5xRmemqmR89BpGoOA25hqA',
#   '6-y0MS5P3QZLmKLUmX0teA',
#   '6RBZfirnzE4NahJTn1UPNA',
#   '6_OAIFxSk3YjNdRJv59Saw',
#   '75FY8ZQx5nOWP0VFmNvWfw',
#   '7D5-a53BLau19RpMu-L3zg',
#   '82_lGisVlstS_ojKZw9qNw',
#   '8kh6Z3c8UHQKmsy0_TbOnA',
#   '99xTcKwadFwSxB2i76GT3g',
#   '9xdXS7jtWjCVzL4_oPGv9A',
#   'A0sbhBYYbg73L8uLYsDong',
#   'CG1Bb2MTraJYTHCPFm72XA',
#   'Eowg0w9AxszjCQyB9R_gSw',
#   'Et2yOijYQbWyR-mE0-z40w',
#   'FCfTUUTYXfZchPvx7tkoWA',
#   'FlDkxuO6MGrW7x1OJTtJew',
#   'GBTPC53ZrG1ZBY3DT8Mbcw',
#   'GSOLNXG5-IPvNj0DPf3kOQ',
#   'H5KRna9A6mDQEJ2ZN0zL6g',
#   'I3Uy20BKx7G-Fzz6hLIeWg',
#   'IXllQQM7LG9NC7uNQ8un1g',
#   'KLLO4MTEI2mDwdakz51www',
#   'Meww6RIE4cFL_kG0aRlbAA',
#   'MqFQqNhMRaizyVRwsea6EA',
#   'NYiL2534CAAbr-ynGVbhaQ',
#   'OX3ArWSP85bK4cdk51tdmw',
#   'OyF6c2he3Aej9itlH8oz-A',
#   'PC62l488ujL8i75jrBiOlg',
#   'PDpEFp0lCsXtGsUO1WPllA',
#   'PJtI7vmojLrIH1qvFrFZkg',
#   'QL4C7sd9PFUOGGpHwe1dlQ',
#   'Q_Wo3rX84Dy-YdQsiDmrWw',
#   'Qlmusk0BBY0kMOd8Y96H4A',
#   'R7I-L_gNlZZyvVspL4Xlhw',
#   'R9TBf8VqGQ83kvdIxkC9RQ',
#   'Rka3xU7Q7uCFdhPbFaQKCg',
#   'RnonJF35oVk94puzrODrJg',
#   'Slg6Ec2D7vEBRmgVUfwkzQ',
#   'Tf_Oj8uWRvXmqkEmntzTdA',
#   'TzkVUJab9Sh0CqDk2sCF-w',
#   'UnQriKTiNsYnyPE3Rt8lTQ',
#   'W4ZEKkva9HpAdZG88juwyQ',
#   'X-BZp1KMgGzKkf_92Y3fWw',
#   'Y1FU2s1OytJGdXksraIGFw',
#   'YNjyv0gfOr2g8lbmUpTnKg',
#   'YvrV_Tc9syF2Wch0HOIT3A',
#   '_C7QiQQc47AOEv4PE3Kong',
#   '_LgI5387qAmMuS8i6h69cg',
#   '_dtlumMepOrZx-k1JEwgWA',
#   'a0jSWZ8xRTffHVF1IldNqQ',
#   'bSJczuohHVko33UT82hnfA',
#   'bp5Mk2d0qofUeF5uLauIbg',
#   'dmylotBWcIExhwyyft5bIw',
#   'e-W6rZ75PrBCTIV3qAdlPA',
#   'eCikDKFbaeYVNdCD2beX0Q',
#   'ft6I8fOrKQtVdM_trVXk8A',
#   'ftDLK3a4E5DpWPLbFo3ZkQ',
#   'g-IXI3v3fOudMsyLPKb-eQ',
#   'gD-MhWOJt8aTfs2KeS_eDA',
#   'htDRn1cXDyimxz6BJWB3LQ',
#   'htx6Uime2SkiE-zC7hxb-g',
#   'kA7f_FA8AagD3a08zsHdBw',
#   'k_-2RlfuhX4Jl9OaJaSO9w',
#   'kdJMzQCyG9X07lEgTWWveQ',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'lok1BFflfV17T04k-Q-G9Q',
#   'me3mlZsR26fV89fMw2uR6Q',
#   'mq8iNBD77TP6eWfFIQO5rQ',
#   'nsFrC9EYtV-0TazHOyMSUw',
#   'nwEMbHDmOAv3Q_us8kVCYQ',
#   'ooUI-JC2tu0J-vavmOHZYQ',
#   'pSgZ6x48zgkbWucfzswkzg',
#   'q6hWVlVeiCgMgM22wt1wfw',
#   'rkZsld6EP8r_iYRba7ug8Q',
#   'sz5SMsTOTAshdfsaK98-TA',
#   'voWjA6zfmXLIbKAoqwBnug',
#   'vvJ0DPrCFnANMS91R7cuzQ',
#   'wtwDcp79klLOLaIjCFHQCA',
#   'xJ3NSwE0xhdtA-tB_y_rNQ',
#   'xZKhj_0PWf9F0ubRyFG5og',
#   'yz0KWVamNhqiZGz7XTClzg',
#   'z0MXYel0okwMqLjgMkKD2A',
#   'zWfzgYe2nT9mHYm_vl1Ukw'},
#  11.0: {'-VlBFlHwX-Pt6Xyzs9roGw',
#   '-lX4ufgPLYubI8rVxNM31w',
#   '1Vc_X9KoRX_YaaYUC268iA',
#   '1b5mnK8bMnnju_cvU65GqQ',
#   '24f-qQokEN2UvBNHMWLm3A',
#   '2S_CEQYBbp8RO1bJm_1mng',
#   '32xxNYVh1Wj33i-tAoggxg',
#   '3CQKFg6AUzmdYHa72-pztw',
#   '3WU1ZobAqXQ07xYoKE2Vyg',
#   '3fVYGQr_ldW2_1QlXJjpaQ',
#   '4Cal2AE6cr7m6nL20Rz2kQ',
#   '4DEO0nDjhS6DifyFP7yJNA',
#   '5fCpIolPWznGdz3D6hjrvg',
#   '6MI36uMz3dni2BVq3Jdd1Q',
#   '6Pu5MKIWbn6FO-oebSSrYQ',
#   '6T6mVCV8a54Xjlw4MdUt4A',
#   '6_OAIFxSk3YjNdRJv59Saw',
#   '6fYIlInL937IBuHmocfiBA',
#   '7Iv-6B0EH-yVo5o_VnykWw',
#   '7n1S1ehbFA3oL8SoB_oP3w',
#   '8SOgWpYKJgiEfTuyXKGdHw',
#   '8uF-bhJFgT4Tn6DTb27viA',
#   '9cybDNxJ7cyNVkmwm-ktcg',
#   '9kv9JpLhzkN3UeWZDrsmEA',
#   'A0RSdFWqs-keuOogaMjZ4w',
#   'AZJpX5slpbZUTU9INbwu0g',
#   'AyuNz2WyV4LOTORTdMGuFQ',
#   'BJauHq_tArHgi0nncImNJg',
#   'BWK7MAUayTZlQ_3PJeaudg',
#   'Bj7DL3SwmYHZYqPduAsa2w',
#   'BsEPhVX7PtbrOkVtnnn1_w',
#   'CR8n4CVq19UqPpJlapQ7jg',
#   'Cm_l5Zp_5ahUrzz3cifdgQ',
#   'D_sIoGDRaLJv0DAIc46MMA',
#   'DjiBIx1d8USQoSQMELQE6g',
#   'EONd-1BeBm04FBLvWe6KMQ',
#   'EYh3aE3mqmQ3k9Laznc58A',
#   'FCfTUUTYXfZchPvx7tkoWA',
#   'FDx_EgHcBvIRGH4UlyuNCA',
#   'Fnr1VWkzAX7cXmEgInrCXg',
#   'GXFMD0Z4jEVZBCsbPf4CTQ',
#   'Gfegg1vwKJJo-EfEujQ-nw',
#   'GoPRuR9prSp_BhgXvcymjQ',
#   'HUcjSm1Lxdn8zSu-hQ7-sw',
#   'HhD8DLES5ZeULKDXmfkOOg',
#   'I6L0Zxi5Ww0zEWSAVgngeQ',
#   'IDjYyBrPW5C2CT9mXsyuBA',
#   'IMWoj619K8ezUmFP8ktXEg',
#   'IZZ_uR2ps5KuuyE0n--jVA',
#   'IgFxKVu_yHlCJsQkTYPPeQ',
#   'J4GlRZkyjbySh7yZfcfxgw',
#   'JEzCDS9mTwTHUqdPiWScXw',
#   'JjM3Nx5hiU004TNB_nN79w',
#   'KLLO4MTEI2mDwdakz51www',
#   'Lu0zbgTAv3KV-JcfePIGbA',
#   'LwBLK_hNI72tZYzuhYp0eQ',
#   'M-6AXSgmDMYcWsF442mzzA',
#   'M0YuK7sLLSA3TfBC4UkUzg',
#   'MDtu8_LFbbkCgzCzIoEWng',
#   'MziuWnUVrnx8R4J4e_QOrQ',
#   'NHdE_ObFj7OjQBB3jjqBNQ',
#   'OED6sS03t872JCN5WK-TZw',
#   'OINbC0rpDVJ5bfxt3LO9fw',
#   'OSi2ColCxhS9oCoAUNbPig',
#   'OWOOc0YjU_kioLeEgo5VCA',
#   'PX_DTu46ZtRiqbF06mR1Lw',
#   'PlaECqs3oPBRo47p85zkzw',
#   'Q1hBOIqr_p6MRnMLawz6cA',
#   'QOPcqO5zvGVZL54917JUdw',
#   'QUEWdnmVCv2Ri8xJATTrIQ',
#   'Rb9QIj-NyRn_giOBN991YA',
#   'ReVpjIDupK_VMPn7ZxPvOQ',
#   'RscMwBafa1cZh94tGlZT_Q',
#   'SA10MB4CEw0YikMuhOxyYw',
#   'SZDWdgb6tgskSlFolkzEdw',
#   'So5ynsJSVB1qaDek1oXvXg',
#   'TIixkkVU3S56Txmi30xT2g',
#   'TLZ3-eDPLhUzfsWO4ad6Ug',
#   'TMBbCDQG6bENJoQSST0XiA',
#   'TVDe34aKHkjaEOtCqffwbw',
#   'Trbe4JX-oLHrrVVPcv0wog',
#   'UA0qseYMXVu0zSLZItwCyQ',
#   'UGefDZNmnBztS0eoXWtHyQ',
#   'UbFkHiEt9S-0mUL3RQ5Ghg',
#   'UeYZgcORV2Veo_BZzdiaTg',
#   'VQcCL9PiNL_wkGf-uF3fjg',
#   'VVH6k9-ycttH3TV_lk5WfQ',
#   'Vz2RN55rTJBGn43K1v84nA',
#   'WvlCQhLQGza1wj0HokAwXg',
#   'XQHBMBfheU8wZbjsy_wOxg',
#   'Y6FyfdZgBpm6lTtqVM1dDQ',
#   'YCPhdj_9t7o_NdN76WKJVg',
#   'ZDV6ocQSe6dkMt-u011xcQ',
#   'ZMRfHHbyTQb_Yje9GhrVfw',
#   'ZW5RwyoMuAjXsAsrHxMv3w',
#   '_C7QiQQc47AOEv4PE3Kong',
#   '_GPds78ik2ZtU-40UyAp-w',
#   '_Mbw_orl5EdXJP1XzklQvA',
#   '_fLKzOl2yx06bZizPPwDeg',
#   '_pnGMIfunC64qz3EKx0nZQ',
#   'aKOo9Kacq-4Wnsy6ilfdQw',
#   'aPDpK9mHhrabKyspSKME6g',
#   'aZ2s_4xvwDCVIvfwI2ctEw',
#   'ac1AeYqs8Z4_e2X5M3if2A',
#   'aklDnLm1843Lvr1cF0iaig',
#   'anj96OOqM159M4C6J2MY2A',
#   'b7V_5q22_eTeHlYzq1bpFw',
#   'b92dSNftvCSPWLC4ZgNXCg',
#   'bnvSozbwKDf8xnsbfe8ZzA',
#   'c3gwn7_ukRwGGIghHLi-UA',
#   'cd-rz-piYMftZtbFU82x8g',
#   'dFf4E6qcQTeRlW9y5yZA6A',
#   'dM2LrfuOqlRHdRKI_FFwCg',
#   'e9YiQo_CGJrnjJXBilAEWQ',
#   'euLOqc_qzh-zsO1eNbyQvg',
#   'ey2F1-Vh60vczNAk0kEnFQ',
#   'f5S8fr9DruZNwSev1gyFWQ',
#   'f5rVYXjpVDijHSF-6C9w2w',
#   'fDIdZaRVraAYvHhNmhWDYA',
#   'fJjwvjGAqDgOILaJrX2WRw',
#   'fNBday9iMr-_VOzPDfP_OQ',
#   'fSsVYM8SEsmM0GHmy9DTTg',
#   'fusQg9Pj0xUC8CzbO2IHrA',
#   'fyVp9XdUrcMxBUn4h1ZmmQ',
#   'g-IXI3v3fOudMsyLPKb-eQ',
#   'geuZssQDB8yblCpFYwoqAw',
#   'gzMlFR9ViVCr_HUYPgqqVg',
#   'hNWrOXZC1Z0AN5jZQ1B5Cg',
#   'hfbZ97Te3T4jeWN6GgsGrQ',
#   'i5oTNLL81YW4Y9-xdGb4xw',
#   'iSRTaT9WngzB8JJ2YKJUig',
#   'iZ7-gwaBWYHiWhez4514jA',
#   'j8JOZvfeHEfUWq3gEz6ABQ',
#   'jQPg8OKiSVa-fwvd-XGzLQ',
#   'k8loHfuD6XfmxlM_podojg',
#   'kFR2U1H-NExtwb9IyZPcKw',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'l4IeGBHXV2E8S8COd9rx9A',
#   'lK-YaoQ670dGJrmaqyJTBA',
#   'n3ZFun1dv52uHnpAKrRIDQ',
#   'n8NLEmKuhUr4fplfjJdTjw',
#   'nB7LcJIvZr-EbJj4oFZf-A',
#   'nWymtJA5PQdtHDPvSmg-OA',
#   'nYzCXMzSk8pjMnYVI6z3RA',
#   'oe-iacnzvyHV8zxaNqCf7A',
#   'oxlgMBR8lf1WGQtMIyrL5g',
#   'pDZWkTn-8qja2C4sZ6CLFA',
#   'pFpQAuoPfhHCbXnHarxxtg',
#   'qF8jkN4q4SajC4p4nKwjgQ',
#   'qKscu5qiEanq7XAduAhHmA',
#   'qltayRFPZ1GiSMeUkeF3Dw',
#   'qyGjCSiWBmEGw_zOYcDnSg',
#   'rAMlyZQe5eFrdLRVQfY4ZQ',
#   'rUxxJi1tlSljiY_kTasUKA',
#   'ryCJdSKiTIngOzU2r7JVag',
#   'sndjU66qBiPsCGmMpvtcQQ',
#   't3OnkntIrz2GjYgeGmsh5Q',
#   'tBk-uwlYrLLqjzO3CPIKjg',
#   't_n6iMoQh3tLIULRTDfzYA',
#   'tsaifr1x7MHWsUngvZ1SQA',
#   'vD_k_V2D_SP_yWQnRoyaEA',
#   'wVrJOXjRrPKIfZbNnrl3ow',
#   'xDfR8rnwsxpM80rIKcvyzA',
#   'xjUtI0-k_d1-ZvBqXU9TYA',
#   'ySgmgIfTm6tUqKRHdK3j9Q',
#   'yoQBK3OUDqWEFoUDE5lM4w',
#   'yz0KWVamNhqiZGz7XTClzg',
#   'z7q_oWGr3GlvYqfiTfeljA',
#   'zafEaH7VOUkd8-9wFlnlmw'},
#  12.0: {'-5DcSecinHF2snC4eLv8WA',
#   '3XTQcobtEsU11sSN2Jn7Bw',
#   '6m4A_ciUZn1G302yx1YV1w',
#   '70QYk-1G2iFDldK2j5AADQ',
#   '7Iv-6B0EH-yVo5o_VnykWw',
#   'EAGJF3Tisg2NRX03oGkmDA',
#   'Eb1XmmLWyt_way5NNZ7-Pw',
#   'Qlmusk0BBY0kMOd8Y96H4A',
#   'e1WJ1qcgF2TBkoYzopeTgQ',
#   'e5fCI12X_GLCST668S4ROA',
#   'hS6KNGCQVTYUdLb2edt58g',
#   'nYPzsOjvida-ne7swSPHpA',
#   'qclZoDz3sjT7v5xOSj5P2Q'},
#  13.0: {'0aUlooXPSltR7-s7Wfsa6A',
#   '0ghzROkZWKWwQKDt1fkPAQ',
#   '4r6N_Fhiwoqo_FqQ7Mm6mQ',
#   'BUk5vgBJIJKTj_izP731yw',
#   'ErLvculzR07OtMqRUjeNNQ',
#   'M0YuK7sLLSA3TfBC4UkUzg',
#   'N1GYsCd5QAchGOCeQ37J9g',
#   'XkQadWW9bUR855KvPZBNUw',
#   'YceW0kQBKMxvol_SspBXVg',
#   'e9YiQo_CGJrnjJXBilAEWQ',
#   'iwmW2mgcn2YdirXUHCsgXQ',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'n_fUROdhfmLwd_mpBi55ew',
#   'oBNrLz4EDhiscSlbOl8uAw',
#   'oFbwMxqaCJfIzAEmwaXD3Q',
#   'tGKYCKSfckujeXNomr-15w',
#   'u08-CrCg_f9sdGD5BtL-QA'},
#  14.0: {'-lX4ufgPLYubI8rVxNM31w',
#   '2XEf2xOj-iZImMeWELkQFw',
#   '2myVMP_l-9f9JIZewm19Cg',
#   '3XQ3YtG4I2XQKeduyPLkfw',
#   '3fVYGQr_ldW2_1QlXJjpaQ',
#   '9OCsSHr6OCSyR91BFIbszQ',
#   'B9_0qF4wFwryCV8IvVEjqA',
#   'BdSyGKYZmh-hg1qCASJI8A',
#   'CRnqAB-ViEfQ0CQGOlEIeA',
#   'EagkHaaC-kUozD3MPzbRIw',
#   'INeL2YsGJRX-QulzFRKKXg',
#   'Qo14LZITJ4fIhSdqOVsm6w',
#   'UUpwoAAZcJyUWOqp81_3mA',
#   'gxusApmuXbfac_Zqy4KbqQ',
#   'kBgiy6ulQRiATWFPZjTPKA',
#   'kcKL0O4hUPeNFyMQwr63Lg',
#   'psVf3ImVOo44xBeh-oVEcg',
#   'tPYkrHdTsYe_-Ty5EPiP2Q',
#   'wPQWqLxY6t3-yRBNPPAmkQ',
#   'wVrJOXjRrPKIfZbNnrl3ow',
#   'yoQBK3OUDqWEFoUDE5lM4w',
#   'zljfjg_zTL3ceGi_Vr4OFw'},
#  15.0: {'0S5nk5wxqUoXNGZ0_DryXw',
#   'HhD8DLES5ZeULKDXmfkOOg',
#   'Nm8N8GU7pYg2rnV_GlwrzQ',
#   'lTqAGjcQHeY3eTXBTIcvkA',
#   'nYzCXMzSk8pjMnYVI6z3RA',
#   't9LiapsQABwMQeiF1Czl6w',
#   'xQ4TAlBO1K78kIizrgLExQ'},
#  16.0: {'-e8RwknT5szoLk9uBZjzcw',
#   '5hvO_zH7B1n2humawoPHrw',
#   '6jKFWxE2fJIhfwbYgwqcfg',
#   '7gtWQMLOEwCxh1I5j6uB4g',
#   '9nkYaCQRyO0fi8SrXDFhGw',
#   'CKvSbAq9M6vPqVVlx1qlGw',
#   'FNsMxoaTa-HCbAxP0Baj9Q',
#   'H5KRna9A6mDQEJ2ZN0zL6g',
#   'I3Uy20BKx7G-Fzz6hLIeWg',
#   'Ix_88gFalSxSCsz5Fbnl7A',
#   'LhtzbTj2QSuNUXFszSKD8w',
#   'N1HTXm1UWrfBWjhqHwcHEg',
#   'W4ZEKkva9HpAdZG88juwyQ',
#   'XnQ84ylyAZwh-XfHGGNBbQ',
#   'Y0izXh4Dv1_YU68tn43Xiw',
#   '_C7QiQQc47AOEv4PE3Kong',
#   'guwb1zuNEMtJVproo0ntFw',
#   'htx6Uime2SkiE-zC7hxb-g',
#   'i_FWONQD1ZBqrNE2b-M5Ug',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'miRxzEzV7OIShLQ5x_Lvvg',
#   'mxZMSFUamk7SIf5ndCLAxA',
#   'qF8jkN4q4SajC4p4nKwjgQ',
#   'qUH2FppY7RL96F5tXzA0hQ',
#   'uO39--k_hrCFgZh-Bl8m8A',
#   'xZileQFJ7h-0QKjtGc9xgg'},
#  17.0: {'-0__F9fnKt8uioCKztF5Ww',
#   '-mcTFLh291MWYECT2bAr3Q',
#   '-s6EMVPCBrsocFDuiMMqxQ',
#   '0LcFxWCdTTpulMZdSiSQ7w',
#   '0VjVuzA5oLmq_-3AfaCHMw',
#   '0aUlooXPSltR7-s7Wfsa6A',
#   '1ddqdY_piKp-abaZ-bGRSA',
#   '24f-qQokEN2UvBNHMWLm3A',
#   '2DTkzhmMpv5fIPKheePClA',
#   '2r3-fBAvSsljWrDLXkiHiw',
#   '3S-u4euLhybQzOuaTAZOpg',
#   '3qEjUW12sH6KOBm86ZDmTA',
#   '3wq2chcgOs5D7f6KHcINmg',
#   '4hR7wf-vaL75ld0_otsTcQ',
#   '4rvAW2dFV24sdGcOLWcU5w',
#   '5AOkxsg6UJQ_CoJTMBDUmQ',
#   '6-VCTlKCj-1RHeC40QaRkA',
#   '6TyzEgzDOhKa82UFjXFdwQ',
#   '8FWAoGPBwRS3I7_FP7u-Mw',
#   '9--QS5ChKDYf4POHKujoiw',
#   '95d60_mjUg2kLy-bhDLC6w',
#   '9740uBf31ch5X6A2ALTOjw',
#   '98UZXU82kKK0YZgPJhTpAQ',
#   '9CRWWbw3iOo4-9FMAO6nKw',
#   '9GQRFx1gk_deIEI9jOx4wQ',
#   '9HvjjSwxxubIhG6E_sObfQ',
#   '9wFFQUCn1j35CYea_dqhsg',
#   '9xdXS7jtWjCVzL4_oPGv9A',
#   'ALjOBKvlyT-lcLFihD4P8g',
#   'AOf_rPp9WyKAM_kgbPjHNQ',
#   'BG8s2nt3V0T8BHFWeTEAaA',
#   'BOtyQFl5FRRlLCXFTqsSTg',
#   'BjeHLwKOlHyV6DJgmZxAjA',
#   'BrospeMqVM_tF9HH0RHuog',
#   'C26xmwM2_OgJJi2BbL3KkQ',
#   'C7WUvmGAz_t4FE_ycOPGUA',
#   'CgO-MoFaV3uTg36xzVeHXA',
#   'ChlcxTEoWBQJXJ2Xb2vm5g',
#   'Ci9fTZBlMjf3dTrwowuntQ',
#   'Crwv3yAmCFweHFKQJJez5w',
#   'DcBLYSvOuWcNReolRVr12A',
#   'EC20rN7JtmAPIxcw3MTzcQ',
#   'EmJF-xSIOaEEOWcK8UOBqg',
#   'F9OFNrITmQ1a9glscJ20ag',
#   'FL2-I_dZF0dGtpgkDqNUjw',
#   'FaY_9x8ZtsuHe5wS2iJM1Q',
#   'FkOTPqfnnKvhk81RZhPy-w',
#   'Fs4T7lKpXVtD5Pz7jWSJeg',
#   'FxyGTyC98dVsVMhPiHXyOQ',
#   'GUgIOkipkxvabF5jQCctVQ',
#   'GXlfX95_luTMPZ_ruNWt2A',
#   'GcJsCFzqvVVwydvBcxmJIA',
#   'GevY5sVM5PKhnAy5BbdeVQ',
#   'HEf0QXnhxrcIWxRfAbQ2iA',
#   'HKLFG2qKkd5X1IyfwYlYqQ',
#   'HUfoljaD3iVbHdQlBAsV4Q',
#   'Hd_SIjvFQbcPuTwnKeiNuA',
#   'I2YZuyG1KjiTbtwfNFHaOQ',
#   'I6L0Zxi5Ww0zEWSAVgngeQ',
#   'ILN6a29XglEjnyaMuMhpyQ',
#   'IQ-FUxpwpibrfOpj6d8Asg',
#   'IZ6vx85mSdC2zp0STFzTIw',
#   'J2Jcksoo1wQ5gC06fEwE3g',
#   'JHyxZ_rhJ2DziKQ9BDsLtQ',
#   'KLLO4MTEI2mDwdakz51www',
#   'Kjt2eEFNoe9Zz8dwkbYc9w',
#   'Kkk5wX6odyIK-ucQXNgd-w',
#   'LggwSfaJm_s4v0wH-kH06g',
#   'M0YuK7sLLSA3TfBC4UkUzg',
#   'MG_wIwRBwyNnCAEMXe9Jqw',
#   'MZnAp5j8gaxsOV-epdDRog',
#   'MqFQqNhMRaizyVRwsea6EA',
#   'MuKoTR56s6elHEI2wUkgJA',
#   'NAMen7YzwlYDs_5ECMnuYQ',
#   'NCzKKh6npVeq-AvlJnGh3w',
#   'O0r7Ocj9XmXvwm8p4I4Nqw',
#   'OAjof8dhS2zScmZh2Xuo1A',
#   'OINbC0rpDVJ5bfxt3LO9fw',
#   'OyF6c2he3Aej9itlH8oz-A',
#   'P4bjdvfuqWrO7rk2eikrbw',
#   'QMHn5GKnGoyKmx2h_OVrxw',
#   'QNB4Um92QR49c1w5cKDbIQ',
#   'R6P3KSFafpKz6bEtHsWz1A',
#   'SIyXCEOHo7Pj41xaGW5jfQ',
#   'SJIQFKTW6uUsOo29w9IHxw',
#   'SYCGlb0WFyyVxD2K9Z-YuA',
#   'SjiRaZoWaDpkCCpq5SsrMw',
#   'SkjUwG0FerzrxnIV8N56CA',
#   'SvB4Z0pan7IKy0IrfNw2rQ',
#   'Sw7qcWQ5_iOUjBZMhSxyOQ',
#   'TLZ3-eDPLhUzfsWO4ad6Ug',
#   'TMBbCDQG6bENJoQSST0XiA',
#   'TcNZXteosegb1RO4O5hREw',
#   'Tgj8vbKxa-t0-nNWZ8T7wA',
#   'Trs9MqShN5PgvtHut74QYg',
#   'TvbJq1a1Xto5w6t4zMUYHQ',
#   'TzkVUJab9Sh0CqDk2sCF-w',
#   'U1DqkgTflF0-k0-WJA2QLA',
#   'UR9dzGGVfcJhHt_mG3bTRA',
#   'UXm-1qI-_AxhC5O3B9La8g',
#   'UbFkHiEt9S-0mUL3RQ5Ghg',
#   'UoZg0xZepdMXbK_2dtT2nw',
#   'VJlR5mFR86Tap9S2qEMFoQ',
#   'VLfiukM-1hlx8_1Kd1uGnA',
#   'WOdqMURCc0CHXUllPZwpqQ',
#   'Wh35Mk7kp6gnF-d_Nl8ZDA',
#   'XR9w5kI2kosXdT8DI_0Lsw',
#   'Xh08NmHdB86LexgXrIxr2Q',
#   'XnQ84ylyAZwh-XfHGGNBbQ',
#   'Y7n6WRhIwnXHU9stwmgFAA',
#   'YNjyv0gfOr2g8lbmUpTnKg',
#   'YmF6Bh0MkjW5qci5KI6D2Q',
#   'YuTrJL0BStMGlvJR2QZebg',
#   'YvrV_Tc9syF2Wch0HOIT3A',
#   'ZDV6ocQSe6dkMt-u011xcQ',
#   'ZaUVTggOTNXvRbMWvD7kfA',
#   'ZdZBmV4R4M1uu1Rwrz4udA',
#   'ZfzTw5exIOalHsGlK99y-w',
#   'Zi-F-YvyVOK0k5QD7lrLOg',
#   'Zt7SfTU6N9SKDvVvpNpoGg',
#   'Zu7_42tm_NYyYR3yb3y27A',
#   '_393npnr0Dw1aGKy83x_0A',
#   '__UJ0y9HkJ8KTswmMZJRlA',
#   '_dDW5rc7MKCOzhRewe3Kfg',
#   '_iDDqhphfpvrDxKjFa9Ofw',
#   '_rO-5jxOEH94TUcorPnSEg',
#   'a1u9Bxrq_fZxl2pgqQUcJA',
#   'aLsbsBbaJzYw3chcdQlCIw',
#   'aQgBYZMH7yrkQVXDPBvFQg',
#   'aROhaLh-dqtt-h6BG-gn2w',
#   'aRfwgRvsQFs9ryUtshaKLA',
#   'bG1rjiksnoTIIucy_7yHOw',
#   'bm2jSmRaHR4EhgtrOuCmnw',
#   'c-Drp2IuAXSqjvyzvOPBzQ',
#   'cOoTIQ0RcudE1R5aRVZzdw',
#   'cmTugbSYlQ82ll8bLDeBYg',
#   'ct-VF8Yqj4GlxEHZ23Arig',
#   'd0E938M2_4kcuULUdnj-Xw',
#   'dGeXdSMah56gEHwZNaRQKA',
#   'dIQGbalj-3I8vixZ4M149g',
#   'e-fXMT8R3j7BKMTh8xn8aw',
#   'e4Vwtrqf-wpJfwesgvdgxQ',
#   'eCikDKFbaeYVNdCD2beX0Q',
#   'eLjXnfYwkr8zz0VhwMhOGw',
#   'fsFZQ2ZbTutgUlnWPhTU6A',
#   'ftDLK3a4E5DpWPLbFo3ZkQ',
#   'fy-vfMF2fQywsIyA3yJQoQ',
#   'g5ogvPhw3PSobtaZFkdEXg',
#   'gTC8IQ_i8zXytWSly3Ttvg',
#   'ga7jZd-JccpMqdSTgY2lUA',
#   'glzIKnlTeUrOXo7tPOW1_A',
#   'hfbZ97Te3T4jeWN6GgsGrQ',
#   'htDRn1cXDyimxz6BJWB3LQ',
#   'iSRTaT9WngzB8JJ2YKJUig',
#   'if57kE6_VfR1nI1X93oHEA',
#   'jPrM21QGv4AgTFLvkpw0jw',
#   'jar_5KMQZtgOseRdUN3L0w',
#   'jrDK6gzJh0VHjttG4SNxZw',
#   'kb1Tf4xwb7CQW5OXf9zwqw',
#   'kdqoDMuvyNedsouc1i33vQ',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'l5cKnwfmnaG4QRZl7ZyNuA',
#   'nx8uirgw7LVjak2rultnng',
#   'o-kjWqR1unEn_ldWyGkNug',
#   'oKlRdVZsH5GPwB0tZmRyrw',
#   'oLwxvBwKg7fmclHU9QuL9w',
#   'oTcezJoCe30NrwiNFsoLXQ',
#   'or4XkblYRyXHxKJuKbhx_Q',
#   'ozUb0F8BxoOm13xXl0GB5g',
#   'q4aAaxdN4wmUZoC6sKEwsw',
#   'qF8jkN4q4SajC4p4nKwjgQ',
#   'qOnDhPSVYwZq0F_s8p6kAw',
#   'qclZoDz3sjT7v5xOSj5P2Q',
#   'qjP2XXjtLdlZ20SISqtAAA',
#   'r9sDW0jV9IfEUygya8j7EA',
#   'rvF-BwyaCHeb30u3Xf7FbQ',
#   'sGy67CpJctjeCWClWqonjA',
#   'tkFVHNahcoerkZYZsdwmBQ',
#   'u7uFQCoHFtBKCtbWUm6yZw',
#   'uHwRntRXSXKZ_F6DKjxpJA',
#   'vBd2-H4sQM1hq3ggWNambw',
#   'vfmHUg7jWnfzLb90vcuLSg',
#   'vxLV9tci88Hsr1G01uleag',
#   'w7Up6RZVcjHmNOCd5v0EwQ',
#   'wHnk0H_5RGBSYCC32SmkIQ',
#   'wMZq2IjqsO0y1DD79tub9A',
#   'x3mym0EmXe9xeNDKQNvBmQ',
#   'xEQYCEOsGsDg1VcOGwGPgQ',
#   'y-g8sgT7WkN16BBe9Vj41g',
#   'y0CPKGHQBPH-maFgP5IFYg',
#   'y2_lmJ3q-cVVR85ulsz45Q',
#   'yIy70vHKF_L3Gy1cu2Wqwg',
#   'yL9j5ASNic_DaDKf9lwMhw',
#   'yz0KWVamNhqiZGz7XTClzg',
#   'yzMxuQYGIqHZCds5J21g2A',
#   'zHoIBH6nIh_Hs8YkSJii5Q',
#   'zWfzgYe2nT9mHYm_vl1Ukw'},
#  18.0: {'8ikj9GaC2oEf_leisl-Wrg',
#   '9740uBf31ch5X6A2ALTOjw',
#   'ChlcxTEoWBQJXJ2Xb2vm5g',
#   'H5KRna9A6mDQEJ2ZN0zL6g',
#   'ObZu0-S1VAqAuCbAF5AFvw',
#   'UH87t9fT_oTLMZfr5iCbQg',
#   'VVH6k9-ycttH3TV_lk5WfQ',
#   'W0FAvNvIQKlL4Yyd25tmlg',
#   '_C7QiQQc47AOEv4PE3Kong',
#   'cF29zGZp1thuOsBIQnDEhw',
#   'htDRn1cXDyimxz6BJWB3LQ',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'oQ5CPRt0R3AzFvcjNOqB1w',
#   'uR7G8I4Cef9D9R340TN24Q'},
#  19.0: {'-mIlmp5l4hKlp1tvHRdvTg',
#   '1QCZS_3x7_JLekGJAqnhMQ',
#   '2iQucreJtTqbEsLczhsgrA',
#   '3XgqYM0uD16T71ZjnEX9KA',
#   '4k-XUWBbeDyxjWdUrEsvLQ',
#   '4n22rhH6sdrAWHm54datEA',
#   '4rvAW2dFV24sdGcOLWcU5w',
#   '4w_TG6uA5bIxnC5tpkOb3g',
#   '6fYIlInL937IBuHmocfiBA',
#   '8NyDM-FDoWEEeEG9XUwnbg',
#   '8yEkaYtBNFS_w-OxbrbEfw',
#   '9xErhLpjFcoA39AFeN3lUA',
#   'ADgeB1sfOGbzCR3LIi-4lg',
#   'AQbmgG6R6hr5KVFw83I-Cw',
#   'AzseSGgDC6bVtMPEYo1CNQ',
#   'ECOUuwE5H1HHE8xBfNAjFg',
#   'EmJF-xSIOaEEOWcK8UOBqg',
#   'FTZZ_79rORWTf6crYDHPMA',
#   'HJqZ_Cp2_-EPC5_IHqbxpg',
#   'HhD8DLES5ZeULKDXmfkOOg',
#   'IMWoj619K8ezUmFP8ktXEg',
#   'JHyxZ_rhJ2DziKQ9BDsLtQ',
#   'Ko7_LgCXdFDzj2t0trVvWw',
#   'MTTbnLFMfvMc5tzed4p4jg',
#   'MqFQqNhMRaizyVRwsea6EA',
#   'NHdE_ObFj7OjQBB3jjqBNQ',
#   'OurEo3zOuyCIyp9uUUQksg',
#   'PP3BBaVxZLcJU54uP_wL6Q',
#   'Ppy-UN5RptIog4AvNnAM-g',
#   'QLUUaTj034zYVWiVl9tNvA',
#   'RLlOK2fL6xU1sfIPiP2QBw',
#   'RTfy6koLz76SG0zNzw4CGw',
#   'TdyHRkxn334JxtUSdGpIiw',
#   'Trbe4JX-oLHrrVVPcv0wog',
#   'TwFOLcctyBEla1eklJs9qQ',
#   'U4X-tzwvTzW8uWxs2KIPtg',
#   'UbFkHiEt9S-0mUL3RQ5Ghg',
#   'UeYZgcORV2Veo_BZzdiaTg',
#   'VQcCL9PiNL_wkGf-uF3fjg',
#   'VVH6k9-ycttH3TV_lk5WfQ',
#   'VaO-VW3e1kARkU9bP1E7Fw',
#   'YxzjYHBkWLwxpvOlcjKkhw',
#   '_C7QiQQc47AOEv4PE3Kong',
#   '_ab50qdWOk0DdB6XOrBitw',
#   'aJe-YsIcKjMvmHE2O0oJ6Q',
#   'ahUKZp4zUSZ_PEbqd786SQ',
#   'e5fCI12X_GLCST668S4ROA',
#   'gTC8IQ_i8zXytWSly3Ttvg',
#   'hfbZ97Te3T4jeWN6GgsGrQ',
#   'htDRn1cXDyimxz6BJWB3LQ',
#   'i6YvzoCYT6vCxBxqD7nR-g',
#   'iSRTaT9WngzB8JJ2YKJUig',
#   'iwmW2mgcn2YdirXUHCsgXQ',
#   'kGhT5VRj2ZBSdXJl6qkLdw',
#   'kYFJQDMHsubrwDfRpEfDTA',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'n_fUROdhfmLwd_mpBi55ew',
#   'r6osq1ta_YFXdmNb34lv8A',
#   'stqWlKEgXweNQSsxOsHjVA',
#   't3fJsOcmghh-MJ-UNXDR3g',
#   'ta5Oi3sezvn4H299MbtE8Q',
#   'vT1zrTTIji2JDhUHjFKopg',
#   'w8AxfAjNq7wU5jHmpLSpNg',
#   'wHnk0H_5RGBSYCC32SmkIQ',
#   'x3JvbhU7wIYcpMVCdMMTqw',
#   'yL9j5ASNic_DaDKf9lwMhw',
#   'yTJ2Ir6CMBzThLK5dmACvQ',
#   'yoQBK3OUDqWEFoUDE5lM4w'},
#  20.0: {'0wZJkj-OnZ7Pmublspl7tA',
#   'C9K3579SJgLPp0oAOM29wg',
#   'EME5hqQLjBD7e2cLryupbA',
#   'YmF6Bh0MkjW5qci5KI6D2Q',
#   'ZTctPm8-lBy0iJ9dFhYhyQ',
#   'e5fCI12X_GLCST668S4ROA'},
#  21.0: {'K3RURR9lIEE4JjOaPt99zg',
#   'TLZ3-eDPLhUzfsWO4ad6Ug',
#   'TVDe34aKHkjaEOtCqffwbw',
#   '_C7QiQQc47AOEv4PE3Kong',
#   'iSRTaT9WngzB8JJ2YKJUig',
#   'oBNrLz4EDhiscSlbOl8uAw'},
#  22.0: {'1aj1hnqPt3rqoB8tVRHLEA',
#   '5AOkxsg6UJQ_CoJTMBDUmQ',
#   '6Ty-KKWq6hLZYW8DWEHYvg',
#   'A0DYN5wxygYnX_sL3HygvA',
#   'H5KRna9A6mDQEJ2ZN0zL6g',
#   'H6qwTMghkuxOoOHEheYo-g',
#   'HEf0QXnhxrcIWxRfAbQ2iA',
#   'JlHO0nd0yXCQbiIIvJm2jQ',
#   'M9OmBqomgvMt0SH5G4prBw',
#   'Meww6RIE4cFL_kG0aRlbAA',
#   'PKZwdGTapRvFsBYh0zQXpw',
#   'QX96jNeZ15qm4xgw5AW5dw',
#   'Qmrw1chFGn3skbWFEyxYCQ',
#   'Qo14LZITJ4fIhSdqOVsm6w',
#   'SjiRaZoWaDpkCCpq5SsrMw',
#   'VQcCL9PiNL_wkGf-uF3fjg',
#   'Xh08NmHdB86LexgXrIxr2Q',
#   'a1u9Bxrq_fZxl2pgqQUcJA',
#   'aYTy7BprrbZ2uvsqPHanZg',
#   'auv_gvtR7fZp9b0mkEbTIA',
#   'bp5Mk2d0qofUeF5uLauIbg',
#   'eCikDKFbaeYVNdCD2beX0Q',
#   'fycH5S7TJL-urUcy6GgDGQ',
#   'gzMlFR9ViVCr_HUYPgqqVg',
#   'jB96BxpnIkcAQ9iF_R75LQ',
#   'm1d3rZ3TWntcGFI9c5Rc7A',
#   'qclZoDz3sjT7v5xOSj5P2Q',
#   'rOsC1rDpIxvNoHxEvNFjeA',
#   'tsaifr1x7MHWsUngvZ1SQA',
#   'uW2oyOCEN3RgS7j2MfUIkg',
#   'xIeHG2cqw7XEqy_M82zA7g',
#   'yj0SWZvJ0tGwAywoVxPT5A'},
#  23.0: {'24f-qQokEN2UvBNHMWLm3A',
#   '7jPySMocq3QkmTalOCJ5mg',
#   'GUgIOkipkxvabF5jQCctVQ',
#   'PFA4CAwNPDR018fmWdQmnA',
#   'YUtYV7iXqiUX19gFBiy9SQ',
#   'aIVk0IEUj7rPaAMeAmBSGg',
#   'fd9KE5qmM-s35H0bBhOnDg',
#   'oCbJpGl8IkH1WdYa25TDBA',
#   'pZXR4SH9fKTH6Pqrmtp4sQ',
#   'qjP2XXjtLdlZ20SISqtAAA',
#   'rkZsld6EP8r_iYRba7ug8Q',
#   'rx4fcNjuqoaEugMPq5PBfw',
#   'yz0KWVamNhqiZGz7XTClzg'},
#  24.0: {'-f7yjjrgCB1zsjt9SnGMdg',
#   '2ukJ2tNmtWfHvpGjYMgVnA',
#   '6ZSLVI8PDkczCp9qrYj_tQ',
#   '6a4gLLFSgr-Q6CZXDLzBGQ',
#   '72wIv_a7AS5JmDUfaIXacQ',
#   '7V9tzovEB26FILijEVaLwg',
#   'AsYatpyVqR2jUTOvs7W2_w',
#   'BjBDHqHhMXSxgyVipccznQ',
#   'Djdg_JBVHKgGNckbEV27UA',
#   'Eb1XmmLWyt_way5NNZ7-Pw',
#   'GwKila2gkEAmYadVFvazNw',
#   'HpLIHgoz3XPTyol5tKKb_w',
#   'JglSBV9cZB_fb1Zqv_nvXg',
#   'Qmxqc_JtDSVscrjh2rdesw',
#   'QtgubTRRFHtEL_fmsMQRCg',
#   'VPNGVGOy8na3GB5y0FkqDQ',
#   'X6ExflwppH41zPcnSRv0uA',
#   'peomsQ8wq84wK1j2RjZnjQ',
#   'qclZoDz3sjT7v5xOSj5P2Q',
#   'ukQv_5rrCEx5NY7ZBZy1kQ',
#   'vLT1DBDuJpchewphXR6i0Q',
#   'w_4xUt-1AyY2ZwKtnjW0Xg',
#   'zeZN6jO3hwoYdmT6U61LqA'},
#  25.0: {'8NcF9WI22e43Sm6JHYhEGQ',
#   'AP2UC4jid1vxI7Mu_Y1sXQ',
#   'GmXC3CBu172Bkb0c6RnO7w',
#   'H5KRna9A6mDQEJ2ZN0zL6g',
#   'IgFxKVu_yHlCJsQkTYPPeQ',
#   'Jw6WbQpwQYsQRWJN66ZkPw',
#   'OWF6L53h0nG0IXWNq1Cckw',
#   'RDIsXBd5h8ML1wSQ7AuKxA',
#   'UnQriKTiNsYnyPE3Rt8lTQ',
#   '_6woRce_3sGy5zDrpbM4Vg',
#   '_C7QiQQc47AOEv4PE3Kong',
#   'dIQGbalj-3I8vixZ4M149g',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'm0dBq-YzfRbRsN4aJF5MIA',
#   'pSgZ6x48zgkbWucfzswkzg',
#   'pXGjRlMs6Nzn59GUeDKsxQ',
#   'qltayRFPZ1GiSMeUkeF3Dw',
#   'rUxxJi1tlSljiY_kTasUKA',
#   'u-wkhjV7CfvGJVY7hGULjw'},
#  26.0: {'0Fd0erJKcQlbnWnPrYJI2Q',
#   '2vvvAfUTpCv_wcK3aKYETg',
#   '317lIGWVcxcVWdVo6ZKHwg',
#   '36_FvBjdMXC949XVYDUb6A',
#   '7_kXuKFruGrrRauN9rLJ1g',
#   'DW9rgqWWzidDLIazmTjthw',
#   'EegNFBB2WIxv9iOOiTifxw',
#   'Eo0psaCr_gcty9QqyUy46Q',
#   'Flj91i3ODKW-RDupjwWFqQ',
#   'I7GoKXrd_k5_ObTWWgkWDQ',
#   'J0upe5MQ5X9MkchhS_Aotw',
#   'Jk2UFmtR6CQO0EIy8RLtyw',
#   'RaD4AOWsvutdqV-kTpjZjQ',
#   'S9WG-ZBwLVj2eCB6_0P0MQ',
#   'TUhRukcZb3tG0cB_X68FCQ',
#   'W9y4JkMqy2dFNwYc3Y5cKQ',
#   'YC6kIDnyVUU96LF_cuHl8w',
#   '_9MTM7D67Up6A_5uTv1Ucw',
#   '_k1CIuPkY-uLFm8lABFG8Q',
#   'bn2jWrB_aXdQP4YoyUVVIQ',
#   'dbuLvPSU8jMxd-DWnZO1gA',
#   'dpwkz52tHB2MCPv53I2aRA',
#   'fBnki9kkjTfepj0HPiUMGQ',
#   'g1Z6PDo72f7E5uI_JAyfQg',
#   'h4HPMMoDcvxlD1xNuVPC6A',
#   'h7TO_IsmLCYmKKDVOOIeFw',
#   'lrowppSl2sk3hU4tSUaS6Q',
#   'oJxsRgj8Un9VAPXpaDuufA',
#   'olTM8BfLhhcRrY6yCWd19Q',
#   'r6dvcGaTEcvN4nUIeS15nA',
#   'rUydZ_RoLnw5DYDyYtfF6Q',
#   'vIwdLdSMmGMjRin9OSxViA',
#   'vYv9PhpNZGhrU8t_pvdlCw',
#   'z8RRZNpjuP2rcHP1VdqUNw',
#   'zvGNZF827KyzLupKiG4Xtw'},
#  27.0: {'-4mDMBfT6N0d-VIUTKVaLg',
#   '-7GjicSH_rM8JeZGCXGcUg',
#   '-FM4CxOg4XXmX_Ebky_SiQ',
#   '-Om8XgP9GZ4UUFbgTRI4YQ',
#   '-WQjN0W4CD5sw2DywN11NQ',
#   '-dVBeSZxtxpHQ3XdL4E4bQ',
#   '-vXGKRBI9qOtNLoptRyaHQ',
#   '0BXnGq6eJuiWR7270TipoA',
#   '0IG9w6YCkh-z5pnfSip6Nw',
#   '0YELKCY1VMIA3gmP2DkHSg',
#   '0kEyHYpI6ixtq87LV6I1Aw',
#   '0reG29yOG8de0y2lGYvP2w',
#   '12SbnXfsthBbBaF2YzhLfA',
#   '18h9q-R5PdlSjkE1DGKHXA',
#   '1b5mnK8bMnnju_cvU65GqQ',
#   '1u2IlvwOMndfuRk9EVcieQ',
#   '1yEGEkkEz-hY4ZZ68fgYuA',
#   '239tY1FTov3pnbZbx4pdwQ',
#   '2HxkdqHmbYGj_BH1bLaiSw',
#   '2Q1R2OhBbAQ581vK_r7NhA',
#   '2y09RYmTXDpGkfqysvNPXQ',
#   '35KHrtM1ZYtyZs1b6J1K4A',
#   '3FPi2yKCIh0Hh3iBg8faYA',
#   '3PlpoDgeAQAreL8FM2LelA',
#   '3kc7vVRl845AknJtUqGRAg',
#   '4FaYG9qKDpDyr68bKmaIEw',
#   '4HE6POeYQtB_k6ziyRoqlg',
#   '4dYOqNZHEcUMfngnomYM1A',
#   '4zhRzZSDhRLYQL2SxBtnrQ',
#   '5HdDg_x1vGgqfERWcOiMTw',
#   '5KcHQxMSGV4lt3BY7ynwNA',
#   '5R6YO6K9PkthkTbXqV9slQ',
#   '5m6gQ3BwWi8QXcZmD4yulg',
#   '5rScKeYVjFk8VahsvJv9QA',
#   '5wwBRxOeYOmle48Ls9kBrw',
#   '69ccjOpx2iFvr1y2qas9uA',
#   '6F4JadEP6ouUvNiIKr8pMg',
#   '6LAp-gSP9Kk4ZvxijXaxIw',
#   '6_T2xzR74JqGCTPefAD8Tw',
#   '6kGguKQkmMITO3n8H8EKOA',
#   '6kX0lZkpfQQmNWaIjpcsKw',
#   '6mL1WHEloNCQfc7a81pBiQ',
#   '6umrAefeyJjKj1Wah4eXnQ',
#   '6yGZ9RMMcW2-sKmnbIWbmw',
#   '742hWlXisoSxhGJmeJNkrg',
#   '7NITtPelRe_oQRsWACI3yA',
#   '7gmgEoLpKdC2nawiBOtGjA',
#   '7ptGQTkwnECXBmUmTF-Z9w',
#   '8m3-Xrqr2dkF-lLz5H1ZrA',
#   '9A1ve-8MfJcUcOGQYCLlKA',
#   'A3P0BQ10fhjmR2skHKNOkQ',
#   'AQ2oJDcBB54fvGwxMiTMqQ',
#   'A_lsaliw6jk7DQV6rTfY_A',
#   'AdT6vMVYy2uFFfnYbWoAsw',
#   'BMKJ3JyD_r_SQ1JXAzo1Hw',
#   'Bkd_k8p0zXxQmHPOmXarZg',
#   'Bs0JwJEUdfhL-FtLjuu3vA',
#   'BsW3-SdZ0X7NYnb-EwwXzg',
#   'CBrD7r4PTCAKc7sP_WsXmw',
#   'CTZEnTsW2JYN2NH1BCAaZw',
#   'CYKj959PZDjweV-CSpssCg',
#   'D9dzy9YIlRf7rGQobaYqGw',
#   'DWvUksyr2wlNiEu0MfYLuA',
#   'DcejXAJp_MbhvdTTiPjMvg',
#   'DghM9cFcE9geVNAtz4GbFg',
#   'DxcI1Thd3vP36up6Dec87Q',
#   'E2l9h35n-BpwWpV5RVye-w',
#   'ED6-QMvrpP2f0gF66Zw0Tg',
#   'EYNHli3Gxd8BKmsLMQIt3Q',
#   'E_Yzg6j5fEBQ0ay-ZwzHKg',
#   'EfdzCoq9JeNFIdUYFqtIlQ',
#   'Envz99GhwMkfMg7LzDQeUQ',
#   'Eop86vwzcYzDiqxqZEsyaA',
#   'F0n-lzB9vqRLdH5Ihcs1Ag',
#   'FLDjk3oA3JpeOfiIORLp9Q',
#   'FQskkrIuNMKRCQJuokI8gQ',
#   'FqxfsOhn13BKlXm94f1bjA',
#   'G2oWC7vWPTiTZt--0bUMzA',
#   'G5sMILBHK-4Qh9gam6GcAg',
#   'GTEWqK6UFJasMsA3e_OAyw',
#   'GtWSpGm3-si4ejOJu07dHg',
#   'GwKila2gkEAmYadVFvazNw',
#   'H96e2s__y-oodr_hkRUQNw',
#   'HEUYDy6SEmA5fptgusn4Yw',
#   'HMjfvm1IWCtfLwniR0EBdw',
#   'HWXk2r8LiAAEun_kTcRbhg',
#   'Hr6aM0s-woIJaW6DJSbvNQ',
#   'HviAzkMvhZbyT8dUH9BkLQ',
#   'I5jxUHS1Dp2rg40eDzyiCA',
#   'Ib9HV7ekw459jM1Ksdiyiw',
#   'IiSXzsFJaFEMTkiUsPFm_g',
#   'IjtKwA7njLjTvZr0nFSLeA',
#   'IkaYcBVD95keDiT25xxX8Q',
#   'Ipkx4Sa7ybn8C6LtTqTztw',
#   'Ir5e0r9HM798lqIYP1D9nQ',
#   'J--R8_P_gfIHkz15R4axTw',
#   'J04F5XfkBHtPSuUmO77iVA',
#   'JJRRJEmis9QlmGnE5WZk8A',
#   'J_8Uw2A_d-H-99MdkYetVw',
#   'JpRss-a6Nb1nc3fUvl3MAg',
#   'Kdce69zftq0fpHEXMojEXg',
#   'KiwskluQ7tMqZqvuf872vg',
#   'Kjd1ri2lPsdrfRmh_6duyg',
#   'L69bxbfNjOQ5yDA1Wtxoqw',
#   'LDZtTWgBKEsg3M0K0s2eBA',
#   'LZGyOPinxoMjeM_RvgjfTg',
#   'LfMWxz9OtZmeHB3sj0Jm5Q',
#   'Lt_RJu8LN4P-YR07v45YKg',
#   'M9M37FllWUIslw2OE9eyKg',
#   'MJ9BrqRBC-Sda5eWNS6WVQ',
#   'MJzk9BpPkwio_BTFLytCDA',
#   'MqrfqmuSgNyFAUSZ-YOToA',
#   'NbgxCd-ImFiiV9mUtZRT8Q',
#   'NwJoFxmYRDxVGXgPtrjQ3w',
#   'O01R-G6g5Ft8iwgy7I6jwg',
#   'OIES_WhdNux3PmvSuPM-8Q',
#   'OR1zqBRTlDSBEDnnAT3iEw',
#   'OUmZYqNbOj-ZgVsnWH8-0g',
#   'OddKlB5d2KQpIP2rJt89ow',
#   'Oq5B0zc5vL0bFCxH7qd9-A',
#   'PK2NvXv7RKvqSSOmzyr4Rg',
#   'PpN7ZMEhfQaNm7qxVZ-nTg',
#   'Ps7Q7BOKzJO4nDTUhbk43Q',
#   'Q08nz8Y6VEDPyho_yJgimA',
#   'Q2T7jA5l-uZu78TwSgcE9g',
#   'QDtqfxuYzBtnAeN90l67YA',
#   'QboMIy08NLnBbLXEsmnDHg',
#   'Qk5HvQpVC17MaLlVIiThhw',
#   'RHMDQkb2XrEp9_zvKIfTTQ',
#   'RmZ9CORyRONwfJYGrPPpbA',
#   'RuPk-ScXo4ycpdnAkpfoNg',
#   'S-aqWmXiRT2XYCLYugdBdQ',
#   'SK5QTllf553tIKs0hGaZQg',
#   'SgQYWN_U5nyKofiCewopMg',
#   'SqnMmUeoWrc5g66wAHOq4g',
#   'St_OHgYAn5czLy0naZwseA',
#   'SwJLqp3ngTotqd3kAmPdyw',
#   'T3Bbtht3jO2izyO6f6W8bg',
#   'T9nNz9-3mfNga0T0Nfzvsw',
#   'TV81bpCQ6p6o4Hau5hk-zw',
#   'TXRBp01bIr60dSGYsu8oxQ',
#   'Tx9kwNLX2lYNqr2weKWEqg',
#   'UGebrYgNZrMzbGbcI01JWA',
#   'UYixLMVmlL761lXVZ36vLw',
#   'UakVMT3xrpbFB2pHdxPjnw',
#   'UvxheDh6Mx67BhvBzfkthQ',
#   'VCGOGpOYnomj7o2qeVHHiA',
#   'VG4yVFNX7B-iONzZlLd-Fw',
#   'VP8HMhVt-pKmqGNmDW4-TQ',
#   'VPEZwyog5oF82gzd9qfcOA',
#   'VVH6k9-ycttH3TV_lk5WfQ',
#   'VWTQpgexQBp3z_HdlYiq5g',
#   'WCNd0M_-1uJNpHP14nQ8og',
#   'WKkLsiO4SxdegSNGJzVWpQ',
#   'WO5nr-4sjVs506BdCLL0aA',
#   'WY7Umhuv9jcQ6fOoOFa4lQ',
#   'WZm72JqVRfpw2Pu3vag9gw',
#   'WeDn7iD1ckcEg7YttkduWg',
#   'WqteSM1GLr8FXefQcIqT5w',
#   'X9e_btDPux6JGqqw8UF_Pg',
#   'XXXpyqzP0B2i8J2eWr2Zig',
#   'XyGRDrgCK0z4CiA6nhwEaw',
#   'Y1dCERRJJ11D0v9Vnir-6w',
#   'Y57sylYCgq2VQJuBCnjPfA',
#   'Y9CWVffIrTYCXE9PVreerQ',
#   'YBq6blbEs3Vc43x-G0mC8w',
#   'YHlZCtNLplWoXK_eoOs9-g',
#   'Zx-dx9e4Hp-mpDV1JbhEwg',
#   '_0QZGrg91aaiMhh7tQyYYg',
#   '_78Lam9Jd0W6ZmnHTvdjMg',
#   '_Glb44hQtdSHOiV6UeNMVA',
#   '_IisHzyWHBuFCUwgmFuGLw',
#   '_NiLHTix7qYc3CTcR4VBOQ',
#   '_P0-D02F_0SgFUuJLtHK1A',
#   '_SWLKuVCLjl6mTae0Y_Phg',
#   '_Sg2klmzH4JxJCrstJhStw',
#   '_zzNQl6ImFw_B64cSdaoGA',
#   'a6kCB2Enbc3xuWnfHm2hGA',
#   'aAjOFpX5SBSoDkAsBSZeZw',
#   'aAyCUTc7y9ZIN1OZ7tGe6Q',
#   'aDd5-AAWriJscf2dTdGOCA',
#   'aI6CFYGdsZqzwyHdW7fvLw',
#   'aes3WRAM4fYRnYjeE8Lm9w',
#   'aqLHq0LCuqgVVjcsjeyTbA',
#   'b6_HDIygAfbG9SZWbZMD_g',
#   'bEw98BIWaAUjL7VNpZ7Crg',
#   'bKaBjDbtwQh_T-3ZpKJxRQ',
#   'bRNtnWlkSQJp_kUjx1p9Cg',
#   'bZUmx_CkQkAtFwAVqVhFrA',
#   'br6Cc1K0_otT9bc_b3mPdA',
#   'buPs3iWmdUBzJ8RTsR9hJA',
#   'bxnjcNGQmxAyoUfg5LXntw',
#   'cQF2tZfLvdb4wg7vxvBRZA',
#   'cSpRppFwXB4xOprhJ1EXuw',
#   'cd-rz-piYMftZtbFU82x8g',
#   'cfFdnSlMmqQoAb0KDk9IPw',
#   'd2HazI4L_0T_4PJq1KiZUA',
#   'd9vapPUlJCSSrltRRKO9ig',
#   'dBCNUSbz5-8nQNrxWo5deg',
#   'dEMsUFNB4ckBFdB90jKLEA',
#   'dOk9uk7GKqKr7e4juSiEfg',
#   'd_eUn7jPYkOhc5rwOfbOyw',
#   'dgyKoIYEYrmRK_hktWBZdA',
#   'e0CA8hTRjk0cVmxW0kYmIQ',
#   'e5l2e_j_NmJnzO3-XNtWow',
#   'eDqPBPit4nCy_qLEE6AA9A',
#   'edsO_ZkOA2NEhYWWrXrFTw',
#   'f7FPMRaMbGiX-CXPaLFCJw',
#   'fF0aVsxyI51ZfCZoN-F5GQ',
#   'fIlR_iCy3m10_UYt6lJjHQ',
#   'fNrIpFcGr8-lMgTQJLRayQ',
#   'fSCyylUhuA9BSakKPFoUbA',
#   'g01cT9A9AkNGz7zD2ubNfQ',
#   'gExn3d0VMMJWlSICsGHGfg',
#   'gHuMBv4kPMZ_TP8FhN8ySw',
#   'ggNLqZxILZgGabRT_NPS_A',
#   'gmYMOcIFsfUnlP_5HMaHpw',
#   'gnWv-PBNfjegWYPiJQTc6g',
#   'gqCHiQ0OiDkARDQzlEFUiA',
#   'gqmQA9TIdmKz3tCnz6DqFA',
#   'h-0hwjiPSiWQD0UXgAy1_g',
#   'h5CW1W-61Bj-0r-zj0dqEw',
#   'hE6YsHHV0fCz_UrGS4o6VA',
#   'hL76rhaLE86ZJvZBuMeb6Q',
#   'hPCOlBgpAaT8w5QdicVeXg',
#   'hxPnlWZmirx7neooZykmtg',
#   'izi_00HlrDk-YDIXfODjUQ',
#   'jA7MZB1aMgQaiNzIdhkwZg',
#   'jHrp-GQ2iSKUgHd_dvnWqg',
#   'jZKoHLLeax-1KRWoUlnttg',
#   'ju3OnrqQ5mprsnTghq1uZw',
#   'jxHXxBESenM-Wzia5Xh2vA',
#   'kAOn-rLmNnm0YM9x6mZ_6g',
#   'kBLMIhzYGoqKm2EK4GME8A',
#   'kFwYrDiiVuaEuw1WIV260w',
#   'kMXVKnMoI9l7_5wEUB4fDA',
#   'kfW3-LmZlKrXq3RndVXxdg',
#   'kmlX0JG-6gVTjsMUnmY18Q',
#   'kpF8q97-b2MDjmnJl74A1Q',
#   'l4IeGBHXV2E8S8COd9rx9A',
#   'lB0QRhfNQQI0-Znf7hkBXA',
#   'lZX5_8qspEXtMJGFQ0-Mow',
#   'lmDeX1e658Zu5rIV3-lvKQ',
#   'lsO4nMqeEPIT5QZ9jQ9G5g',
#   'mVjKb4-y9VPWp38CBim4sg',
#   'mlMUCwhGacYGDTFZPZGFCA',
#   'msp4nQ9YPzSA7d6fVbSrAA',
#   'mzAFaxDgKEVhINViBlyWvA',
#   'n2aY_LObgko-ko4grWzLyg',
#   'nRBYoJP0ergYGJAsfES0OA',
#   'ne7QDP3iqkjLqTi0jckyBA',
#   'o644e8y0gqcrjhX_l-HY8w',
#   'oH7kVPQy98Dvh1dNVvkwpw',
#   'onLwomlGswMhhmOEAeAVEg',
#   'oqP1oQEycpp4J6u5YebRoQ',
#   'pEw7LP0CItZ5TPA9PkBzwA',
#   'pVwMHUYFMuwmRe6M--ZzwA',
#   'pdh91rffpM9QptHSXjJFVQ',
#   'pyZjYbon3ZGw7RHEeqN51w',
#   'q3qHHAMG8v748fe2z0EsCg',
#   'q6Rln6JUAr8ALqbTNZs2ag',
#   'q7h9Feqfh3AEJTzAwru07Q',
#   'qAyZXMjWo5mW21Ql53iThA',
#   'qJAWrsvNv74KYAoo6TAj0A',
#   'qMrWq1CimcZlE02mIBH9SQ',
#   'qQndnEgepogvQdFxeOUyvg',
#   'qc-xhHvmyzyrBAOZUeleig',
#   'qkJdBYlWWRfYOQKI6BgnQQ',
#   'qnTszlGgzUBu44tdQR7QgQ',
#   'qplX-RwFUVWNAnd2Nuj7HA',
#   'quk6TFDQyuQ4g0KuIb9qUA',
#   'rDfSxhW6mNe9ldS3giOTCQ',
#   'raWAHw922t-tF4BPyXO9JQ',
#   's0yq79nfOrJEYoGKQLoxkg',
#   's29wxFmnoRdckDjwmPi1RA',
#   'sI0B9BdUVPXFtF27RI3Fdw',
#   'sjH_9PYtfGhzZYsaZmPPzQ',
#   'ssfYhDhEuc98I7SCENXqnw',
#   'szad9yEwckNw0P3L5FGyNQ',
#   't3mM7pSpQKg7hOy0PeuKtA',
#   'tmHGSdRJG0BD3aJ07z2ZrA',
#   'uPUh99711tvY772laBbBbg',
#   'uT8IB-CHxTUmW_wD62bA0g',
#   'uZyu2mvqg3Cc8lf_tiBRSA',
#   'v1msvs2bf_LwGUnIcCgSEg',
#   'v4jzYZvLqCxPvJLmYzMibg',
#   'vH3bNYj4M3oYNwjcTJKbpA',
#   'vKTTtmv9-xoM9IecE68DpA',
#   'vYk_ZieerrxyPpaOn1WG7w',
#   'vlGBKK9Ti07MYibNQbTq5g',
#   'wAVa4NJk2Qg5vgWSlpa-QA',
#   'wFES5bGDiPANW13hNHnXOQ',
#   'wacMqAA_9USygYvgJAkfgw',
#   'wexGsdw5Wz85-hOBx9r2Tg',
#   'winkCYdiTroKdbPbV0DfRA',
#   'wnaSIsTY4IDAP-kQ440fcw',
#   'ws2gnWU77nydKJB81GXT9g',
#   'x-8eEo5Vo4Eb27sI8oO2wg',
#   'xQE1fuwKCXJEBcJgSSCNbw',
#   'xh7mQ46QUMswpugKJFmppQ',
#   'xp96gnfbb98nnr2-GqYEtA',
#   'xzpGYyGD_gk6jBaZ_e7nCA',
#   'y5OovQyNsJ77O0AR2XPIww',
#   'yChy5PZZOAPf4WhUUpaZ1g',
#   'ySn36gFeTJ0fR8CG-Q2DuA',
#   'yYGCoJfHANvtOZ7e51FU5g',
#   'yeHLiKNp0hyR-ig4M6us-w',
#   'yui1n1JawiW9g7RR62a_wA',
#   'zLN6ix7txwpfwRKFi2MfCQ',
#   'zTGzoge9b_U1m7lExiHqgw',
#   'zZ46gP_VbzU9l9cNAQJpCQ',
#   'z_7TZeTXsDH6MmkPHQN8nQ',
#   'zaeNGZfmOiBzGVqGhRfX3w'},
#  28.0: {'3aCIpZgIeDwB1uQBAaPbKQ',
#   '4x_DhrjTcrpieMkbrrCU-g',
#   '5xRmemqmR89BpGoOA25hqA',
#   'BbnL_wJLB-EHvFx0dXuAjg',
#   'ILWv3aMVbZUMjcMSTGgStQ',
#   'KquItUiyLRxiasJ3P_xGMQ',
#   'O_l8AIlR2RJvNPq4CDMbtQ',
#   'RloVMlIr8kP8Sn609loBTg',
#   'UeYZgcORV2Veo_BZzdiaTg',
#   'Vz2RN55rTJBGn43K1v84nA',
#   'Zh1JlS8z9pqJ39vs1hW7Ug',
#   'Zl6sqGgp3X4HAdr9t5BE8g',
#   '_ab50qdWOk0DdB6XOrBitw',
#   'a3w6LxhzD69RD2yYb93N5g',
#   'dYYkzkiAQoOtRjdR0kcspw',
#   'sG-Z7aIlkmKW7EstH1dH5Q',
#   'sitve7-2mPUQQ2bV8jLCRg',
#   'xwjUyOwIQuFNaBCxhedwLA'},
#  29.0: {'3Ym00dQ_oqZ0zunGMLhX3Q',
#   '4ZaYKh2zZsSFSvcNM9zwFg',
#   '4r6N_Fhiwoqo_FqQ7Mm6mQ',
#   '5JjZQr91HqTGUhpdHaV8tg',
#   'AGlh4ZDv6jnoiYfz7At9mw',
#   'AZSNnOWAX5zGq7KqKjzkrQ',
#   'DKyJMM2209QrTgclzoCUpw',
#   'IdIOZSbnLRcN1dG5PDXDeA',
#   'M0NT6MBWg5-76wyQXMzJWg',
#   'MHcOkWBRXi-OxkIlCSlsOQ',
#   'MqhQlbkYd9dShIEcPbmS_g',
#   'NtfDrs753JK4dLFmjPJl7w',
#   'OOv7OvZlExF2Z3Q569RtEw',
#   'P-PBH28Ck3jaUY660VTuAw',
#   'RQTRnBmDXXNWiM1-1LEqWg',
#   'TDRw3TX_lMAqwsHRfVOiRQ',
#   'U1VdxazyPMrmf6sCZFKL2A',
#   'WTPTuGK40bJc5H0UTMTWuw',
#   'WnVNjr9zVEpK85T7dbAfEg',
#   'Yu401DtSmkXpJhgXnQcFrg',
#   '_aKr7POnacW_VizRKBpCiA',
#   '_c72muPOhnfUqLRBNIAAcQ',
#   'a3chKz0NwZcwCEhDqr9MpQ',
#   'bDwAOwlB-HkOqvSfHumfng',
#   'd3dw3YihB3WuU1Sb_i74-w',
#   'dG1pPWaVoIHWMIChKjfolg',
#   'jJDvC05yT8Xb5R9vmMa69Q',
#   'k8hFz4Gty5dHlDV4Wt8FqA',
#   'kzHH50fET6e5nVqk8IIl5Q',
#   'oHAAlU_Yts_avncJK0hJpw',
#   'o_5z2Qt335Or-TTnECOIiw',
#   'pBl1CSeYKbWMSrqgglIMDw',
#   'ufscOQH8rFo4BHIHj0au3A',
#   'v45E6gg6MrAziTepkiWByA'},
#  30.0: {'6Ty-KKWq6hLZYW8DWEHYvg',
#   '7maX9XE-iMlelyr5B7YyHg',
#   '8-0EBUcwlrRMWhSNdT-5FQ',
#   '9HvjjSwxxubIhG6E_sObfQ',
#   '9ruUYAz35q6mgUpxb5zZhg',
#   'FknpD7tLt59-6ozV3Pk2Vg',
#   'Gl2wxwEVFEc9Kb9TXIXQ5A',
#   'I9DaV_jfAqUkVcr4x2XhFQ',
#   'JhpRI9m71ybWHkAqRdL0Tg',
#   'KCm9f7cROQ-f0iyYxFxQog',
#   'OSi2ColCxhS9oCoAUNbPig',
#   'O_l8AIlR2RJvNPq4CDMbtQ',
#   'OlOVRlcEstxKK_6hMjy63A',
#   'R3nn80FwXhANpjtJU7-DAg',
#   'SyKHFYhRzW1hlwDga5EWWw',
#   'Vz2RN55rTJBGn43K1v84nA',
#   'Ynbd79O142LHhFWZAce1TA',
#   'ZTVVJzlYpQSbkPJvXh3ZZw',
#   'Zi-F-YvyVOK0k5QD7lrLOg',
#   '_ab50qdWOk0DdB6XOrBitw',
#   'aRetE3hno9ISsRMaRaobGA',
#   'cTSczU-9-cYUEM2DlNJcQw',
#   'd_UJWp4IlGS4sgnjE60eBw',
#   'ku8cAVBLaF_4rI-yK6gNnQ',
#   'nF38_8yQWPHB2SYUFsPsBw',
#   'oBNrLz4EDhiscSlbOl8uAw',
#   'pym7c6ZFEtmoH16xN2ApBg',
#   'wkakne7bpbBaDrT6btLFfQ'},
#  31.0: {'-EHrU_DwtX2Jv4NbAMppTA',
#   '40ovn6SAc5c7v84bRzpB2Q',
#   '4D1bpaK80jcfniPSo4WsGw',
#   '582qelAj3_So_uj6yuTzKg',
#   '7N6XfRfK1G1XTnI6XdZotQ',
#   '7ZeKBOTge-pKO9hSRjFJTA',
#   '7v51SIyxTPyfee_Wt0efbg',
#   '8jXmNMrGJ2acUG1R-D5e6w',
#   '9JrZDH4Mq0BXQ2GYIJmo-g',
#   'CJ3t6dw60CdpflWKe3b78Q',
#   'Cb6tGAb2wcFYOg8WvT5X2w',
#   'Dzm1y59cLFt8OjTsZRUC6w',
#   'EXriY53Mvv60OMrLrJktZw',
#   'FvzSJKFwhTYkpOh0TZD_nA',
#   'GwKila2gkEAmYadVFvazNw',
#   'IBWzg15XkNO25hOpQHM7ig',
#   'IhWg_9ceUBP1z7fvxlA9Uw',
#   'IvaYjcuPXzgutKanTeHSRw',
#   'J-Go00lYW4f4a3lLLtoh_A',
#   'JBtEFotg7cKcbZZQsysJ_Q',
#   'KCpO2BB2ib2S2bzMlwPgxA',
#   'KftsSJhTvpNAZlWRoLxr8Q',
#   'MbNcVhRqpNPcvgFzWgaxSQ',
#   'NhIa6lf-D60Tgdj4RN3gjw',
#   'NifsdrLXQI13EQ7po7Z7Bg',
#   'OJ9BTwxBGfVvynZnO1bd7Q',
#   'OuaqRGlscxMIqUoN4Vw41A',
#   'PC62l488ujL8i75jrBiOlg',
#   'PRpjxJNfK0I_em5CNLYpVA',
#   'QFQ8PQit-SCD5L1rUsvTBQ',
#   'QKPCzNPs-QiBIymqWhE01Q',
#   'U6NKHV_-ce1LvVbt4vjIaA',
#   'UnBs9SfFGQ7TpE_3uYIqfg',
#   'Vpv7_M6dpg92GwappohXlw',
#   'W-gap4C7bKfV6OE94an3qw',
#   'X0vPZIkbUj22afBQz5-neA',
#   'XZRsPZb30NWjgqZBSumsSw',
#   '_IXMwdME6klp_VVxIoEtWA',
#   'a2iOC9RIV18gDCHl8cUF0g',
#   'aIVk0IEUj7rPaAMeAmBSGg',
#   'd26VEnmSq_r2wJ35L9RYUw',
#   'eNhbpnZ6p7TDvAKU4XTOyg',
#   'eiuYtZB62adMDVRkDyLQPw',
#   'guUDJ4iPHHFt1vE6YR1jeg',
#   'iEikRs0aTF0tAriKsLB8PQ',
#   'iLtnmQ7H_Sj-rOEgcpWHxQ',
#   'kF89t83G376kVxW37m5pnQ',
#   'laIi1mYcEBif7cU8A_kLew',
#   'm3tc5lXPk0VQB8gjYANXIQ',
#   'mt2fNZpZAd-PU99aK6wf9A',
#   'nFDvzfl84x1y3NMBcjqdbQ',
#   'ncyt6jLL3iAICPRGFe7Ihw',
#   'nk96iwJV1_p2HECYQW1ysA',
#   'nuZm_f6EzuJTu3iT_b6DGw',
#   'oHywMcurU-Z94mLGRNL85A',
#   'pDR3n7cjtbTrkgDxfUUDtw',
#   'qOdsOVOM98hHj1SCRscjHg',
#   'r5TrH8oLwfUcniIwf1m7sQ',
#   'sQYpmnFHGaYXSDbQUTevEQ',
#   't9LiapsQABwMQeiF1Czl6w',
#   'tMsQnjwF4T8_a_JbfbaCFw',
#   'w_4xUt-1AyY2ZwKtnjW0Xg',
#   'yEHnyZkYPROFuSf8jDfVVA'},
#  32.0: {'-Tskf8WK17rb3ZfeFuRSWA',
#   '-_tJHdUMvTO4xiSPsIDpgg',
#   '-ojG1NfFYuHN_oGsGK1W8Q',
#   '0JtYKzRiG1Rad7nyhObEHQ',
#   '103cmgKE0n1Cb8QCEXvbQQ',
#   '1LL54pSLD2MS1u3OvCzygw',
#   '1klQuTKmJr-eMQPuFaQ5fg',
#   '24f-qQokEN2UvBNHMWLm3A',
#   '2MHNvEPEGxvBxZLXM5ESpg',
#   '2OoJO2EX0hireQxTK6ho8w',
#   '2QGyW4T6E_4iSltdx9i2RQ',
#   '2r3-fBAvSsljWrDLXkiHiw',
#   '39UfyJQEbMB7h4u_DxrZ3A',
#   '3YqUe2FTCQr0pPVK8oCv6Q',
#   '3db1R99-mdSvx3QwryJSNQ',
#   '3fVYGQr_ldW2_1QlXJjpaQ',
#   '3uTpN9lxvTbJpx9KkH1v0g',
#   '3wo9jODQnuvBm8Gkem6qXg',
#   '41b1cZSlkIBA_87-jCcXlw',
#   '4EaRjOTNIo-72sQMf-Wykg',
#   '4WdDY97x4GdMYtyk1KQMnw',
#   '4gu8bjsgJoZrilDr_u3pEg',
#   '4iKNV1ijEygUYWvx85w-jw',
#   '4w_TG6uA5bIxnC5tpkOb3g',
#   '4xV3C_5VXQzAAYGIwJ_4dg',
#   '50Q2uIgwUqmWGLjn_1HSlg',
#   '5AOkxsg6UJQ_CoJTMBDUmQ',
#   '5Gxej8xEPPeJC-N8-x8kuA',
#   '5J62KjDfOgHkDbKdkAqEsg',
#   '5bT-bq-u8rEjBopZg4LCeQ',
#   '5uPdoWQNjYkrpRmy9AonSw',
#   '61fGIOE0DxjkZXE5wFDTqg',
#   '6Ty-KKWq6hLZYW8DWEHYvg',
#   '6a4gLLFSgr-Q6CZXDLzBGQ',
#   '6xA3Zg26SbaftWvzf6Rn4Q',
#   '6zEWIsb6Lhr3BeoC3gm1lw',
#   '75FY8ZQx5nOWP0VFmNvWfw',
#   '7EzofjbnuwDU5MBaSOmh0g',
#   '7UxXTerYUimY4Su-daewjg',
#   '7v0lDJAYdXjGHcZzhYg6-w',
#   '8ASzjS3ITg5bQSyObsCx5w',
#   '8NyDM-FDoWEEeEG9XUwnbg',
#   '8eDkw7CE0NKqMknPIu26fw',
#   '8jXmNMrGJ2acUG1R-D5e6w',
#   '8lKmq3q0sxraES0p0uZINw',
#   '8uF-bhJFgT4Tn6DTb27viA',
#   '945COKKrD_bTDznBeHqksw',
#   '99dN-202N0EzRqdaOA_eRQ',
#   '9V0LMtO1riRw9-pUuG4NFg',
#   '9hUAOvJlS49CJyRWsx22fA',
#   'A0DYN5wxygYnX_sL3HygvA',
#   'AOIPO0mvg6khJg4EYS8Jag',
#   'AYYNXdF0GkzxIQ7cX9nNvw',
#   'AZJpX5slpbZUTU9INbwu0g',
#   'AhVvuzwWQU__CligbY4r0Q',
#   'ArPLE_RTg0h7yzkN0KwzRg',
#   'AzylMkpWl-OLWQLMKVRoVg',
#   'BG8s2nt3V0T8BHFWeTEAaA',
#   'BIENs1tadPhlsv87rFzZBw',
#   'BRJwJjDrnO4OA4MTCK3mcg',
#   'BRM7OfdwyiXOH_TrU-aPYA',
#   'BWK7MAUayTZlQ_3PJeaudg',
#   'BfkqPDZ2Tt7Afhp5gn3wfw',
#   'C9K3579SJgLPp0oAOM29wg',
#   'CG1Bb2MTraJYTHCPFm72XA',
#   'CIVPalBUxIRUJ04ig5NTFw',
#   'CKvcCZ14SeDs0GgJClFk5A',
#   'ChlcxTEoWBQJXJ2Xb2vm5g',
#   'ChtsrYW3VMynF38HVuJdBg',
#   'Ci-PLI7xdQ0RPqZ2TnHffw',
#   'Cls83yBk3rWusKdshSCUPw',
#   'D4Uw7MZVGd4QLZF_dxk-Pw',
#   'D73evJ9PZKxO3E5TaThe3w',
#   'DX7UvqlJqU2_dt2Nn6mMHQ',
#   'D_sIoGDRaLJv0DAIc46MMA',
#   'DorCmYVDR5wcCVvbCAvzEg',
#   'ECer60ayJ9r_ICCkvosREg',
#   'EME5hqQLjBD7e2cLryupbA',
#   'EmJF-xSIOaEEOWcK8UOBqg',
#   'Enf481q4AQpAK4uWiqoXbA',
#   'F9OFNrITmQ1a9glscJ20ag',
#   'FGe8_MFciERzA_sM7FNJNA',
#   'FlDkxuO6MGrW7x1OJTtJew',
#   'FlyfDPS41F8R9f5KHA8g2Q',
#   'GIo6CTonm96GbnHqLsw04g',
#   'GMqkvnOMYekDAnpzv6Upqg',
#   'GXFMD0Z4jEVZBCsbPf4CTQ',
#   'GcJsCFzqvVVwydvBcxmJIA',
#   'GmXC3CBu172Bkb0c6RnO7w',
#   'GoPRuR9prSp_BhgXvcymjQ',
#   'H5KRna9A6mDQEJ2ZN0zL6g',
#   'H6Xs7cFxUe-WfINaL4mVyQ',
#   'H6qwTMghkuxOoOHEheYo-g',
#   'HDnaNdHEZpQMYXo-ZHHG9g',
#   'HH9x7WcNQR3cnwkHo_YL0w',
#   'HHKWz02LCPCftIkP0ghptA',
#   'HhD8DLES5ZeULKDXmfkOOg',
#   'I0I2mkCOPTYVSLpc8A8VVw',
#   'I3Uy20BKx7G-Fzz6hLIeWg',
#   'IBWzg15XkNO25hOpQHM7ig',
#   'IIGVuXllRX3yV1GlIIgHkg',
#   'I_FKWKPVpGts4q_HzJ-0mQ',
#   'J88JV53EPyDjj7lT0Cm9wA',
#   'J96Q1F6TamXl5FCp4wDeoA',
#   'JIMo4CQNZiLYa8Tak4EFiA',
#   'Jw6WbQpwQYsQRWJN66ZkPw',
# ...
#   'KOkkX1YK0kRuxysrwsUD7w',
#   'KPmFv_Ou6ddauV_gYauWzg',
#   'KU7XnbHB-EBOCbyXH0VVuQ',
#   'KV_byKHRH3bYLWjnW3EduA',
#   'Knk5_SDSCx7slFb2rtBgOw',
#   'KnsY8rh5tigp5t6WpilGdA',
#   'L-VNs3YquPGKVsXl2Ze-Yg',
#   'L3SkZnSVFgDHUiJ6_H1UPw',
#   'L5LLN0RafiV1Z9cddzvuCw',
#   'L5U9dBXYKNDyWp4lk9j9QQ',
#   'L7HqDGVSyNIYtmxGD8xfiw',
#   'LIcsCCOYqBO9k2tiO4Mrow',
#   'LLuw6bOw7AXh1k8_We6YwQ',
#   'LV26xDdWViKGFlJXizyHcg',
#   'LalGsMdQmJeIvCgqHVZZsg',
#   'LgHYTrrRhajfo4y8jkVQPQ',
#   'LlYENa9mr9V0vILUO4xGlQ',
#   'LnI2XHbeEiF4a0yTkJf-Yg',
#   'LnswHpNxGc8exgNXQ7eslw',
#   'Lw_8MDDspsumhB37n74nNw',
#   'M0r9lUn2gLFYgIwIfG8-bQ',
#   'M35BYETJon2nKyim2lxRZA',
#   'M9s1QoMF8AHqsB9j58bKtA',
#   'MFy3OwuMFdUhr29IIy_TdA',
#   'MLAElwGFXThzlMP1vJ1gNQ',
#   'MOy8qGtBOoJzRnHnv3Y3JQ',
#   'MQ5AbyTEk6IW3lG4GuLutA',
#   'MQo2LU5h8JhSpN-PBgvA_w',
#   'MRmc3lCbmuhy5FP7RwCNjQ',
#   'MWNwy-TqIEwPIuB3bukCoQ',
#   'Mgaxy0pJAlhAjdNivhu82A',
#   'MnfqewXhy_JtEGY8ENXRyw',
#   'MnjCw3oaM0Hq39bjONDU0Q',
#   'MuKoTR56s6elHEI2wUkgJA',
#   'N2tq-0lhGucwixmXRHjE3w',
#   'NB5XTBuLVCn7c9Lu5SUqKg',
#   'NDzQFHW671hbB-aArOy12A',
#   'NIIDHVkiPh0jAkQ02BeOig',
#   'NL_RDDQ_uPAT8t-x7hINvA',
#   'NiXwGOozHmBbCN3-GpsYFg',
#   'NvMYRJ_wPJmt4FFsEF7O0A',
#   'NwdPpWY0HmeCgE4NTlb0Vw',
#   'Nxa362GcR1WWK2og8uJ_sQ',
#   'O66AUt4swFQjfo4xuqYGOw',
#   'OGd2l-ngsBy0409KbRETVw',
#   'OR1jehTozILIG4FzoxJcUw',
#   'OWOOc0YjU_kioLeEgo5VCA',
#   'OWVQwMK59coLok5_qsX3-w',
#   'OYbHaM1Q5JKFLDwOhRetLA',
#   'Op1PKEFSdADkc7Dq_1D18A',
#   'Op8RPQBkiix8nDWsFvhnqw',
#   'OqYmqCBS5gUByt5khERwtw',
#   'PEYgtOhGVoBoWwTJJg4M7A',
#   'PKugkEPK9A2J51CB9Dsgug',
#   'PXCNGIxi_kQ5_V77j3FrNQ',
#   'PipWZrOMuoetKcKkHSRUkQ',
#   'Pkg4NA3NilK3Z-_uM0AKTg',
#   'Q1hBOIqr_p6MRnMLawz6cA',
#   'Q21JJcmmGH365PkvFzQbEg',
#   'Q2T7jA5l-uZu78TwSgcE9g',
#   'Q6eP-wX_xOI0bnZqIQlTGA',
#   'QABhvVoWsJwDQsR6Iy70kg',
#   'QFzfm7Xe8i_7M6oS08c9YQ',
#   'QHUj7c1MkC3jnkku5S1Pcw',
#   'QJiA9H2GMdp0Ge1zmQpwLg',
#   'QWENxNxNNW2jhQi2akONJA',
#   'QaOTMn7BVBx3xXrjRlVnCw',
#   'QdzyfsO1kOSe64IjN1p97g',
#   'QfVeoUCXT-CRrp0tMcPs4A',
#   'Qp9p9n8GHy4wLJv6yk45kw',
#   'QuIdNnX1HuYGQRspUYS1Aw',
#   'QvB0NRTGDplwnfPZGq8chw',
#   'QzwtJd7pF9fBY8WHVQfKfw',
#   'RMYjaB5krFGCtlOLf5TBwQ',
#   'RNzhLU8zy1L5dBkjRK4xEA',
#   'RTOIDrDonj9tgYHHSTuu-g',
#   'R_Wi9jh57H_OzzAVWO71Bw',
#   'RedEws4XD_Z36RjsFow98w',
#   'RiC_-68qxtDJqiIs5mRR6g',
#   'Ro2iz0iZch3hTfSqrUvXQg',
#   'RtGZdKWTYMNU6zXJdLOVqg',
#   'S2mZQ0vIL2gYk5qHKW76vA',
#   'S5zpryZNidOZUFcfznfhaQ',
#   'S6tR7vBAg-3b9mGLB13-Ug',
#   'S8ZFYEgMejpChID8tzKo9A',
#   'SBgr-5n-kV3EeZztYsstUQ',
#   'SFN5g5eexukcaZkzoiYQYg',
#   'SjLYEsv94TjmSjG2Fc2piQ',
#   'Sos54CF8gTPHnROpBRWJoA',
#   'SsRsSSifdOtKAQDGST_m_g',
#   'Sw7qcWQ5_iOUjBZMhSxyOQ',
#   'T4LfF6fT4_5UuP6ZpMjUGQ',
#   'T8m0HbUwAAoYsn3wrqqHzg',
#   'T9fF2OXS7FObKpmaxTGXVw',
#   'T9hQBMwt8-3okULfDZx-Lw',
#   'TDBRKkYpqaJdVNqbGoDi5w',
#   'TEZ6tQ92RU5CYfDIOgOU8g',
#   'TREeB3OyL2YvyoenMjWTLg',
#   'TWFSeE74pTq3l687qpQtrw',
#   'TXV-qLmXmgxM1QHCATQOuQ',
#   'T_GeXNYY_zO0WpJzBxQj4w',
#   'TlVR0GNI6MsJyS0e74OhnA',
#   'TpfJI1Vs5YdQ7B35VkfpYA',
#   'Tq5jFk_BMSJG8-flqj5Bgw',
#   'U-VlSil0ZxpbfBX6TxKXbw',
#   'U2hkeMI-q4cS35QolJYN0A',
#   'UZCe8bfQdU38wXzURA0RfA',
#   'U_NagvNEa4k150qLgul_zw',
#   'UdbHkdU0EfG-RmVxnvO25A',
#   'UeemkxzMST9c7rKucGCJmg',
#   'UiZ2-Zq1SqZAC5HnfNNZFA',
#   'UpWlqQ_jrTF4JAtdGZL33w',
#   'UrSj-PThC681ei_iIAAwMA',
#   'Ut_46Y-g3BsokjYGUHJ5Ng',
#   'V-Dm95vQpkdaeSzehDEgpA',
#   'V-_RomYtkgVlNB-KjwFkYw',
#   'V4AndHJfOgAwP85wJxyKXQ',
#   'VJ-c-Yjj1qv7dKS5YaYoHg',
#   'VJ4Z1gN_gWK2IFQ3Id8Z2w',
#   'VKC7v0O5mNli-hKmftRbaw',
#   'VLYc7i37TXKh1nzxVLpzsg',
#   'VOIlYgva7npz0GtX-PQvqQ',
#   'VUPA0aoSemYyPY1UnIV2fA',
#   'VUkBbffnuUpKX9MKRUt4yQ',
#   'VXuHnpO4AvZjgfL5KmEEug',
#   'V_tkg5iqbsR9TcrivrDgzg',
#   'Vg_6rTzC8M0dJNTKIcCspA',
#   'VioQ-O-wJYgrW1fta5nhug',
#   'VlTwxhPtKWvWxg6VSS9uyA',
#   'W-GmQyyKIskcS3u7nHprtA',
#   'W2lEjwsnCqm3SmjleJ0xlw',
#   'W8Z4rXYkmZlEVSaxIVjyvg',
#   'WUV4xv4xpg_n9OMpT_ICHQ',
#   'WkKfqNbnL6oU_xJblmtN_Q',
#   'WtUxi5n8KlQdfgHZfB2Fqw',
#   'WtxtrT2CjXmabCRxvBI0ig',
#   'X1cAKstyGPdqJEY1-_rSYA',
#   'X5fWO9e82EICHXzzs6eQMg',
#   'XCY5mYQv-6Y-uOZEOgOhiQ',
#   'XF2SR4yNnIOGRGH9goofuA',
#   'XI99CG-lx3OH7oVeRTejvg',
#   'XIKYdKWq72zUYsq8NBxcCQ',
#   'XOcxiOreD3SnoFK4fHTrNQ',
#   'XWoGfbjiWCiciUgXEJzKpA',
#   'XX2PSfT4xuHq0yuoPIge1A',
#   'X_cvnwvszRb0iBsWsjnzwQ',
#   'XipwoysF1dPd0BJfNBo2Zw',
#   'XtuEHDssiPvi1dD2GBAZoA',
#   'Xvysm1k3vp-2uvUrrUwGbw',
#   'Y4krSkdWSlJR6XW0SX00og',
#   'YHHGQiH06KH4XSlNm_XsEQ',
#   'YJsxg06slxmdPPax-7Dn4w',
#   'YPTYOQO8Lg9BtHsRwYBY7g',
#   'YQlQ9jJT4zOY-_lW61msLA',
#   'YSgcojsb2kWHXNLWaGCuBA',
#   'YVvm1Q3ir5TET0f66FOX_g',
#   'YafU-Kipt3QbHbHznyqHnQ',
#   'YctbBmhrWLXw9-yCYHPknA',
#   'YfGl5XVVjGdearXRuZQFnQ',
#   'YpGPZ-Zg89BsFUWwCXoaBw',
#   'YpMEDBDkz49VOiueB4OOlQ',
#   'YuatbQ1sfTFnmfgjzVDv-g',
#   'ZLrqw4KCwKyBlVqycUfNbg',
#   'ZSLFWH6qmfhr6_p0bDSRIg',
#   'Z_WZq3uFGqvtjsFl6kNBQA',
#   'ZyzNGyuZP5zp-KTlHr-oFg',
#   '_78Lam9Jd0W6ZmnHTvdjMg',
#   '_HO5ubZyfVKVWytSDZy1tA',
#   '_HmySkpAYC3ewKzPiMpjSg',
#   '_Rj-WaJMlpdhM3hNzrjgoQ',
#   '_Wfw4yGny3BxKN-OIXWq-g',
#   '_ZnlXUVbNgLSa5f3pIjdSA',
#   'aI3B47Y_AUYFP5K5JAYrlA',
#   'af9kqxyB0Y8DQx8qGwKiOA',
#   'aoRv_tZfoGHjXkPqy94ryQ',
#   'aryPR5d4zccypuNmR3Efyg',
#   'awA0KQacd4k4GUSKP8aliw',
#   'awN-Lg5jlhFpsMdXe9WXvw',
#   'azp2wLevlaVODNk26MDfEA',
#   'b13EoceGelGyrIPRxxiERQ',
#   'bAUQSI186koK1aP8k3z9Ug',
#   'bHCG1tA5p8WKGXgEFxoW5A',
#   'bL6JBa3Q7c3SQh9vdrrZhw',
#   'bPsfG2mW_21Z03sbEKwUXQ',
#   'bRRlWJeuPtmI3UuGhh43Wg',
#   'bU3Z7IiLY0-6sswo8WXeKQ',
#   'bWeWDz7lAn9BWTyicBRmpA',
#   'bghJT62oG5RHz2Wf0yZ5SA',
#   'bjj7HIgdC04IhctuMMIF1A',
#   'byKTdpw1FyvR7fMfNSOQCg',
#   'bzjOYERJv5YwW6Q8lUBcJw',
#   'c-bNmSeRVifpRTegX2aGZg',
#   'c4T4fWfNdnlyOgBN0a5JFA',
#   'c6zgxvHn5j816s9DDAFYjA',
#   'cCD0ad9z0ZJjHLZsH8bfRQ',
#   'cEgsHkAnpYQbA60pIIZYKQ',
#   'cHCRC7r9irhK0dIum1zeUw',
#   'cM3C8AT3IhOIM4ccBofuSg',
#   'cN8F-BmoHoS9eCqIHMtlHA',
#   'cXlzdE08id4K1YhmvzZzrA',
#   'c_4c5rJECZSfNgFj7frwHQ',
#   'cbOz9CwZCMf1Bxgzgms-fg',
#   'cbr2Db20L6P50CsxsX6c2A',
#   'd3D5R3uP3BjQN6m_60nFww',
#   'd3Qumdqjwj62dEYZ7lc6mg',
#   'd4GRmLdkPIsJBeOYE7fuqA',
#   'dACR4DqvhmNcT1DSyr_XIQ',
#   'dG-gZOWzn8iO1Rvv_fbXxA',
#   'dMbCdmoXHFXPueEiBP6wsA',
#   'dNFGbezaxeBR71BdpspKqQ',
#   'dRdkZwlvxfz78mkAF-99-Q',
#   'dUAtskhiZO-MQnCBJRBxxg',
#   'dYsSSplrU88w4i86K5uQSQ',
#   'dnOZr9LepBOSgQi2Jrls9A',
#   'dsfRniRgfbDjC8os848B6A',
#   'dtP1I4R6iiCsV_4WUKg0Bw',
#   'e6jPIzZNvzVXYJDtVVIF7Q',
#   'eOuSlKYKSTDdDVPYQ6sSsA',
#   'eUcELoQV3rBt4TpS6DO14g',
#   'eUoV6GeeP3GPm9Q3LK3apg',
#   'eZCt3doDaA-l4sg_OM67YQ',
#   'ea-jOH9lTXot2Cp7lNAaRA',
#   'edOq9mAFpg48tI9pwwWNUg',
#   'entPgyZ2zCQ_WWmQdMVhww',
#   'erCGkXWcik3Kij95vShPVg',
#   'fC03dk7N8XV-RzGh0UJgmA',
#   'fKXI9-xXF5ojUu2Ozt9SBQ',
#   'fOhnSqmO4XY5vSI8whVKSA',
#   'fSl9CIn1sUbdrAl98zmjxw',
#   'fYwZcxcBzYJYFBHJPGy6PQ',
#   'faYU9nWyhiYeSwiP05ojvQ',
#   'fchpEk-UJf_AUz-51LEidg',
#   'fk1JfQQya1FZnXwEDURG0Q',
#   'fnAskN29ZOIefCOB_J2sjQ',
#   'frsWe9bmMOMIBOBNzsCTew',
#   'fswX9sbAcZmDirBwi_KmTQ',
#   'ftDLK3a4E5DpWPLbFo3ZkQ',
#   'fzYu9Rh-oqlg95QzkbIO0A',
#   'gGK9oTurV0N5UxPGUs3_sw',
#   'gGmqCZtOAUUqWLUJiL-Ydg',
#   'gLpp7kjR9Zg6ypG2lRjAYg',
#   'gOs5qwT8I-_qXH0HO_M3xA',
#   'gVlBpk6Cmz4FlIPUiKj3bA',
#   'gadHTtm2cEOfxWMQSYCUQA',
#   'geWUsomkOnF5LF4jdpJw0w',
#   'gfPDLZimZu1NtBIDbeXetg',
#   'gjCU_-A0bRP8paEpat2Kvg',
#   'gjYMjwyUGjY004PLo3cC8A',
#   'gmYMOcIFsfUnlP_5HMaHpw',
#   'gqCHiQ0OiDkARDQzlEFUiA',
#   'gswcSH_ueMgNAz8KYakIEw',
#   'gsyyVQmvT9A2nAgUi7VUag',
#   'gzTpGrvPpwlRpVjQHbU_lw',
#   'h0vaA8cPdjabzotwa6BsyA',
#   'h4lnuvBIEL3wefTe9VozwA',
#   'hTbh7GvxD4bzsamttFyy7w',
#   'hXGIMryL90iWW-gPzYEpUA',
#   'h_ylhvlDpJAhoSkdlBoQgA',
#   'hc_Y4nxyM2RUErsOcox9_g',
#   'heWvcO-gLZtOpqwZOkIH0A',
#   'hjpkwT4j2-DDfNQayxHRKQ',
#   'hlX3mIE9PMTf5TQYHVs7lw',
#   'i2H9kFPMAM7kT6t_8uRCMQ',
#   'iANK-Pz1tqQpbsAmMC0Png',
#   'iH3LWJ6yisLnGEnd6Ch29Q',
#   'i_ebZdLk-SePyN6VQYdL-g',
#   'ihGH3GrL9FyIXojRFcaRMg',
#   'j-iDK4aQmAAxveOqwiWOLQ',
#   'j-qtdD55OLfSqfsWuQTDJg',
#   'jHvCRFfAr_VBCtmLIDFQxA',
#   'jKPqzmOcwqfYBqSk7DS3oQ',
#   'j_MFw1jIyDU_Nt-J4wKCHA',
#   'jbJTF1zVmZsk4hea8hoeVA',
#   'jct6fw5FcG4eTjjML-F7Ow',
#   'jfvNWChH6Q7qynCG8bWRPw',
#   'jmG_QxXXfz2cnw9dQCXJLQ',
#   'jnge13lFtiLGXQEo5NwSYw',
#   'joeRm-_7T0XTkMdKo2nbaA',
#   'jqqLV2rmylDbr2sHdt31Jw',
#   'jrev629orqutl4DwZbox-Q',
#   'juBH0j95bJVWs642WFCe-A',
#   'k1_j2d6W8Ij4FIAuYf7-rg',
#   'k9ASnJ6A-nBZhdwPN1NjtA',
#   'kEfaWUNbXBuiuxdX4ETpIQ',
#   'kLW1e26tJgCbQntpklZiDw',
#   'kUSyhVKF8Pw2HYJGj-vyUQ',
#   'kfe_xEH4ppG8AeAPdqqCaA',
#   'khJNtyRfPwQ0ybr3tPeZ3g',
#   'khn9lsIDvoULtuGP0zYaHw',
#   'kpK6SmxIiNoGPNhlEGiL4w',
#   'l4MAy7LGeyVWm_GeFSx3cw',
#   'l7l9PjOiysdzJGS8pjkT9w',
#   'lItMh_MFnh9Bf2m1m9wN-g',
#   'lN_9tSK-zUZyCAkVykKfoA',
#   'lXFpW475fKlACmyyw9_UYA',
#   'lZ2hiZ25W2lMbW-DqoCxbQ',
#   'lgrDv-9XYWoTBuGByGshYw',
#   'lo3zYtvPB6-iVok2C7HsGw',
#   'mAL5Cwdr-GTMaM6HrzRizg',
#   'mAgjr6kjRqCFk8JWPvobuw',
#   'mE4D25vY8SNxpNOZZtEauA',
#   'mFd-j_KM90IOamGmoN5AQA',
#   'mNXeMZ2a3Y4paAUyZz2LIA',
#   'mUrkyChBfFC679O80poJAQ',
#   'm_MhARWbbYZIPHfOMnnZ6A',
#   'mc9V_wG4QyRYew9_S8R44A',
#   'mgpCGxAMyHmyeGKorXefvg',
#   'mxz6YKVNVZvL3h0QzTQlZg',
#   'n4PdRDOWgBOhke7AqCW3FA',
#   'n5_-q6KZ5VCfHTZXh3nsvw',
#   'nP1HqTxrDQD-psxUCLrpkQ',
#   'nU-zF9XbQehltHoi_LwWRw',
#   'nYsNsyIppe_DTueBha1x9A',
#   'nYuwfmjaYdeJgZU_Q_ugaA',
#   'nlgOITwq3VPfiJSLpb5u9g',
#   'nrUPzM6ekI0Piz5se4IsQg',
#   'ntiIq1FNqduOyyowMFGh5A',
#   'o279ck8BVmVlhI19kixJ7Q',
#   'oAenM-Xo_mBBP7neS7NKpA',
#   'oHvEgLH6pAkcrPmeR1l3UQ',
#   'oLEyFAZNGMqMLeyV6n7Xfg',
#   'oM9ZFIgO88Hu0ppDZPjuwg',
#   'okNELZ0_cx8GFyRFcHYAqg',
#   'onLwomlGswMhhmOEAeAVEg',
#   'ooUI-JC2tu0J-vavmOHZYQ',
#   'oqP1oQEycpp4J6u5YebRoQ',
#   'otmz3zBEA4KvgJ5r8K5PRQ',
#   'p7UGlPkE3Gagm9Mq7aHfYg',
#   'p9Dd6AjOawHGGzcUntYr-A',
#   'pA-bRSE9Iiygp2g254umUA',
#   'pAFtOcz710oLQ-e_J6AIzw',
#   'pDghOix5B17eZTtjDsQ4_A',
#   'pM97VC3MB7CSoZLIhcUJeQ',
#   'pPZk4-MXRKoPM4muPuiLOw',
#   'pWuoHHu0LuVrD0HjadDygg',
#   'p_qSQwShIgQnNxGcajI4-w',
#   'pbOq7LK6lE8gvB_WWxCYkQ',
#   'pkNKcNeb0sfy7jR0zGovUg',
#   'ppV8AwESFjlG5FSRXdvtyg',
#   'prZjGYZFtZ05e80cSEYyjg',
#   'q5tktYGvDCazS4GxfrkZbA',
#   'q6Rln6JUAr8ALqbTNZs2ag',
#   'q7t8M6-6nn6d7md12_EA1g',
#   'q9HeBXQBnXgThOa9DPIhAw',
#   'qDsz9yDUoTEjT47W975S0Q',
#   'qH13binX4ke_R1j3QNXccw',
#   'qJAWrsvNv74KYAoo6TAj0A',
#   'qSy3Ue3KlzFFXBKwZTbofg',
#   'qV-fAuhroG1am3WpNobEng',
#   'qauNuzGr6cmAuT7K7FzX5w',
#   'qsLIuY5iERjJ_PJRwZVeRQ',
#   'quHx5Jj3bpUWpizBWfk3dQ',
#   'r-Ssz3aqWGMnYcsoVFzshg',
#   'r8DNf74pfvCdy29fGuwAoA',
#   'rEQ82fSKZBbVtk9h14whog',
#   'rXA6s5JChbYlyqSbbkZboQ',
#   'rfsjwsB9ACTQ-FESh47iUw',
#   'rfyx5Ydw2rUWqotxEzT94Q',
#   'rgkz13vQnU2WFZBQBMqMAg',
#   'rncZirFO0DmWEz4mUg2NrQ',
#   'rzLJskZrSPj6hJHOPmJ0TA',
#   's29wxFmnoRdckDjwmPi1RA',
#   's30pUay0opzvriFweACWEA',
#   'sEDPuN8EAD37PGZY6GMDrg',
#   'sEiFwUjk9esYl49JZFwvBw',
#   'sZ59rIvpI6MZinRBw06tMw',
#   'sikefl5Nj00MNQ1OUyCEcg',
#   'tARR9jhv5gi9TjsfSVmjmw',
#   'tAYDA1RuZfG88zF6Pzp8cw',
#   'tB971SQcyzBs-nqZl1_PjQ',
#   'tKfEDYtJqHxPvTMbqSPTJA',
#   'tM-ObyoUno83kylE283iXw',
#   'tYqIKRQjDCywDVkbfUGSug',
#   'teFjQxUqT8c-yxQdoILDVQ',
#   'tgdhpWSIqw2u9rNLokZKjA',
#   'tkyHFPJ3dBsjE2hA_tk_sQ',
#   'to6rjQskEIczYUxCSGPh6g',
#   'toyrKJg9cZgssxGfQ_kRgA',
#   'tutL-M4mH3GA8JtYlpBbaA',
#   'u2FUWB2xMipayzmNmJ2Mhg',
#   'u4WC_qHGn03jwNdVmW5vaQ',
#   'uAnhBDbZ9xVTmcM00mVCsA',
#   'uEWsfftrJ7ukPv1xyMVcrg',
#   'uQ9Soh0jzRIqPl-S7DX_ig',
#   'uWw055j-6t1u25yRNF-gBg',
#   'u_S84xiDCRJ3CV204CIYuQ',
#   'ufGB0jjQx6J01IKgYCOj5w',
#   'ugfoID6LrdwiqYUSdhkqAw',
#   'uoU7b-XfnWJfJ0jVa7_Uog',
#   'uqXYVxIwoEsFFjEHBlMZQA',
#   'v5IbyC2qHFFCbDk1IEyBvQ',
#   'vEfA3V3pCrnigUFlLJ3gLw',
#   'vEhuYWMnJq9XmWp6JOjYLQ',
#   'vGa5Xwkp1zw4kmANvL54Zw',
#   'vIg_WNUAZHXcqe-9JdWJ7w',
#   'vKbCtJEwGnew-BpGIIzxJw',
#   'vTVe6iR64IBPCDp1Bl_kug',
#   'vUrTGX_7HxqeoQ_6QCVz6g',
#   'vWRdL8B9o2CmUmfJgNgMqQ',
#   'vbJlMZlABeMao3eEjCAGMA',
#   'vf81tOiPd08VGI28EkB6OA',
#   'vhGl4WDtyvSd1Ml0b_FaFA',
#   'vs_0Znpr7vyg8zoxPl59sw',
#   'w0g9q4BC-OFdByt-AYePNQ',
#   'w1drxBdIeFllmEsvH_3a6A',
#   'w2O0CQ_cIeje-5VM77SR0g',
#   'w3KNRp4pdDRHrJK4a76dPA',
#   'wAVa4NJk2Qg5vgWSlpa-QA',
#   'wK2G-v74dCEzmGEUtKgOKQ',
#   'wM4Zy0_yibPty__-WMiSSQ',
#   'wMWRpzjKgwIef2yJ41RCGw',
#   'wMmvlgv_-K2yLx1_IDobVw',
#   'wMyHVb54Ne9SNasa4kjOCg',
#   'wOFbUo9D-JSdMeuUgLyL5g',
#   'wP4m78FJc-fyg8fLhHQ-ZQ',
#   'wPViqOIThG5W_p4FKGqjrQ',
#   'wSZQ5qnYwiukmI0fKBA2fQ',
#   'w_4xUt-1AyY2ZwKtnjW0Xg',
#   'wazRghDjVEiSzTt9WXCPOA',
#   'wb6JLGExZ_u0xVRvG3OT2Q',
#   'wdJVH4bfDmchM6Dug2rqFA',
#   'wlUOgJ63PmhkX5ms-QGoDw',
#   'wo9kN5iSlUNG6HIH7OLurw',
#   'ww3YJXu5c18aGZXWmm00qg',
#   'xB_YNhUqfsvKOfyZHwQsnQ',
#   'xLYj6MYwEIs5HFcBLB7cfA',
#   'xe2L_RvBNgkrVburQrfW_Q',
#   'xnLnBfilhX5X-KvF8ZX3iw',
#   'y29Da2WKi8V4xk4tOacEjQ',
#   'y8gjlpJA89qDRCLC0JQaew',
#   'yPxNNSmPHKO3m_kq53D4Jg',
#   'yYMY4TUCGys5fFju6zODbg',
#   'y_dB-WI2TtDk9w2ZBagnNw',
#   'y_yVztTCNphhSYTPW6osSQ',
#   'ya4ky7GX7nTWPW40-YSAQQ',
#   'yeHLiKNp0hyR-ig4M6us-w',
#   'yf1fXCSYCKvUGUgv5KaInA',
#   'yiN9dBRcABtQ3FuqodAZbQ',
#   'yyvFGYfw0azW5mA_th8ndQ',
#   'z1IpqKeH590-5i66VHUBNQ',
#   'z3jfgtlDBww3jTPLosPeew',
#   'zBs8GENWVLpX7KcBIPiB0A',
#   'zXTO8GaLmRPATr505b4GQQ',
#   'z_7TZeTXsDH6MmkPHQN8nQ',
#   'zlOmh-5zowu6NYm9WhT-Rw',
#   'zobY3ws9R2pgbcP0gOImcg',
#   'zqEmarWiEUQ5jl9R4t8CnQ',
#   'zsDjnBHyJsYfkdry96x75g',
#   'zwBvdDWFQpYJE1UMDTlSyw',
#   'zwsxq_H10uUhWUYHlNtmdw',
#   'zx7XemDyT296vmKnFtZSyQ'},
#  999.0: {'-KoF5X8toS6VBY3DvNeuDA',
#   '0RxW0oN1s4zgNh6uiWVPZQ',
#   '12SbnXfsthBbBaF2YzhLfA',
#   '1Efjww8n7WtKtKTgDqjgdA',
#   '2FnoLyEO0nq7g2Wz8x7Z5A',
#   '2LokHe7GtKZD9Q6w0dRe_A',
#   '2VgdPHszJdhOxzVFBbUPAA',
#   '3Ce8r1K1O-2JKSMXdXID-w',
#   '5Jta7dTc7lteIyeMfLUJWQ',
#   '5d6Re2uKakZvY-QPJgTvUQ',
#   '609Lr-Hvo3sr9amdiimOJA',
#   '617w8MQE3z1szmLvs0WfCw',
#   '6LH5CdxH-zQHkJfm7VIXMg',
#   '6M5r34Sk3mC6kCVXLYKrag',
#   '7RVde_7MH_muKQuoc_8xIA',
#   '7gtWQMLOEwCxh1I5j6uB4g',
#   '7zEVu7s5dHGscMUfRu5GaA',
#   '8SfhajQ-SsvhkxLgINvozg',
#   '8eDkw7CE0NKqMknPIu26fw',
#   '8pqdJjefYq-a9IBSJJmKwA',
#   '99e7bysta1myyrQogFEWUQ',
#   '9ocQBw69M6V3N9LUafw2dg',
#   '9u4_k8-XC4RFETCeiQdO8w',
#   'AlyKaJRNi_2lj5y96QtjCw',
#   'AmYpyArIwjZVnJLRPXEpLw',
#   'Awkrb1wzFxz5w1Ixc9W3FA',
#   'AzWwhJD-w91OJxpqUBnssA',
#   'BiBwdFcG0ynK50_g7zJTOg',
#   'C_UGT4dyFaG-_-ohBJLKog',
#   'D73evJ9PZKxO3E5TaThe3w',
#   'E3QSrua1cXWaurPitBhKGQ',
#   'E_h2yNoagLK-3ODYwMPErw',
#   'FIDLmYEuCtSj_rc8lqaKFw',
#   'FTnY5qY1ftgODV0gGYbI6w',
#   'GBTPC53ZrG1ZBY3DT8Mbcw',
#   'HRdeb1f2JYk13-VkXKeeww',
#   'IDdVpQSDPe_VSXvUU68JwA',
#   'IE-5GIHlAINr0zO4lrJ_Lg',
#   'ILn5k61JhHO3dHmv_JVG4Q',
#   'IkLp51a_x_0CPlg0qMEqNg',
#   'JNBuXPEjE3eavcIUvUc49A',
#   'JODu4xqBU80zZ9mKKWrbYg',
#   'JrG4NINLspXPNhSXg7Q07Q',
#   'K72JfZLdNRWlMSC_hCr1uw',
#   'KBG3GV4WHU-iLLSWiapbJw',
#   'KDplhtRYnHOCnuIjIGR8fA',
#   'KJScP6bDksIDN329d6s8IQ',
#   'KZl-0F4hKwhKSLPmT-A6dw',
#   'L3IMug1NZOITEwNoDz8JAA',
#   'LAL-W7lTr2krLkGpTcPIXg',
#   'LNMi7I89I9NI3bQz8LPetA',
#   'MK0OMY_u9unl8xSqjPLtMw',
#   'Ob01LpWh81jAtzpYirBxpA',
#   'P2Lm1g_RztvIaH4daQsXoQ',
#   'PcamveJ7jyN7MtoBbhf6Og',
#   'S-VD26LE_LeJNx5nASk_pw',
#   'SA10MB4CEw0YikMuhOxyYw',
#   'SyEcp1qlzXcb3UuMPQXVUw',
#   'TFnGJlA5l_HDdzGDkNTdTA',
#   'U4DpkzcADkXFZzYaX9smjQ',
#   'UBX73ZWgCdgom4nv0UeGvg',
#   'UCMSWPqzXjd7QHq7v8PJjQ',
#   'VNvJuCTMdGBj4lwC0L1Ghg',
#   'VPfbGIf3ieDrKuWheOjSLQ',
#   'W9dDiZnNgBwmsoue2r68Sg',
#   'Xh08NmHdB86LexgXrIxr2Q',
#   'YpGPZ-Zg89BsFUWwCXoaBw',
#   'Z4PF4EtM12L7nwOHZHFJNA',
#   '_rgb0rZw1Dmd_ZAW4AM9vw',
#   'a0sN6y6fDZ5HtBjUimKukA',
#   'aRZV74C9w723hu9A-C20gA',
#   'aj3ESi3I6WNzGWp3j6OehQ',
#   'atZ_olNKXOG4rEr6mccN8g',
#   'bkxtuHXCL7GR51FiNdextA',
#   'cYTF_bGZh2iIwt1_zIlcsg',
#   'ceGWN7KegQj0JFL_zFjsuQ',
#   'dLXkx82ZMsR5NLkCRtg0Dw',
#   'ddCKwEeLTVxP9e36ptRakA',
#   'eTrIVMySUFERsxo2ajRaWg',
#   'fTXSAVnzPkHqCzA4l6896g',
#   'fusQg9Pj0xUC8CzbO2IHrA',
#   'g33s03KL3BTPgTPg_6r_Kw',
#   'g8rHp5ViSj3MGP2Yyqx52Q',
#   'gFPvNMQSJe6Eh8895K8ziQ',
#   'gtiGtVIWIXsGhZKWdzVMWg',
#   'haIljRs6pruzNI_4fZrjJw',
#   'iOFbMitGdfU6i5xm4nZ8Ww',
#   'j8feOxyJqlIJWOi8su2qzw',
#   'jUVk21Kkf7awzvnj8oci3Q',
#   'jc6PRKXaOwQeKtQGXoG76Q',
#   'kBgiy6ulQRiATWFPZjTPKA',
#   'kmKHBCTec-e6H4aK7fD8Ag',
#   'lxb27ohlkrJrEv56O2A2qQ',
#   'mhrW9O0O5hXGXGnEYBVoag',
#   'mtvT7uRey3F395STFRM1Tg',
#   'n8yGo_YJneGjOWQHNHLj8Q',
#   'nF5QByCz21MY0KLtSoB5KA',
#   'nYuwfmjaYdeJgZU_Q_ugaA',
#   'oNGQMJmwwPWD1ELyAV9Rjg',
#   'pi1CtS1L_Rd1NcmO-un1cQ',
#   'poviu-6n3iaRE4gdQz6OYw',
#   'q9HeBXQBnXgThOa9DPIhAw',
#   'q9WA6PqTLnB78DWPu5YJ5A',
#   'sczJMRhzdeHXi80lRlrGMQ',
#   'sq3BcLyY4_jZf-zkO2itDA',
#   'sy7ADvpBA7SfHwbY-Y_5gw',
#   'tLVnL8CqQYiMU6E_aayYog',
#   'tVELQMCI0485CPvgtTlMDA',
#   'vA5MHe9LqNQcp8k_CaFkHg',
#   'vhGl4WDtyvSd1Ml0b_FaFA',
#   'vhar8sfBN37RE13z9CXNEQ',
#   'vlGBKK9Ti07MYibNQbTq5g',
#   'x7gEX6dthpJvoOafV1XHaA',
#   'xB_YNhUqfsvKOfyZHwQsnQ',
#   'zJmp_J8SUNosLxk6borpFg',
#   'zZ01WQlcpI1_n806WKV3bA',
#   'zkevOUm1kDU7PUKte4GKpQ',
#   'zujdPV3HT-Y-CKE1GgkMHQ',
#   'zzXDi0Pdv0s84M-oQaIa_g'},
#  ...}

# %%
# Compute average stars per business within each cluster
cluster_business_avg = df_recent_reviews.groupby(['cluster', 'business_id'])['stars'].mean().reset_index()

# Convert to a dictionary for quick lookup: (cluster, business_id) -> avg_stars
cluster_business_avg_dict = cluster_business_avg.set_index(['cluster', 'business_id'])['stars'].to_dict()

# %%
user_mapping, business_mapping, user_business = get_user_business(df_business, df_review)

# %%
user_business
# Out:
#                        user_id             business_id  stars_review
# 0       razUB7ciYZluvxWM6shmtw  --30_8IhuyMHbSOcNWd6DQ      4.803491
# 1       3YhG4h4Ok654iVfqdmkuRg  --7PUidqRWpRSpXebiyxTg      1.940845
# 2       VyC2fG4dcMG07nrxh4jLnw  --7PUidqRWpRSpXebiyxTg      0.976479
# 3       Q5jOFJYhIsN8ouJ1rnsLQQ  --7PUidqRWpRSpXebiyxTg      0.966943
# 4       gdcRlubKDmslUYFPHUp1Cg  --8IbOsAAxjKRoYsBFL-PA      1.939110
# ...                        ...                     ...           ...
# 985727  TkwnhxZfy7AFW1cEIn5u1A  zznJox6-nmXlGYNWgTDwQQ      3.851865
# 985728  weuxfeOxeGs8InkBS1ivbQ  zznJox6-nmXlGYNWgTDwQQ      2.949528
# 985729  Gix3hMYtxiiQd4Pg626GfQ  zznJox6-nmXlGYNWgTDwQQ      0.978447
# 985730  rB1vREB0x_uynI0ADMs2iA  zztOG2cKm87I6Iw_tleZsQ      4.939903
# 985731  7UEjHw0g1Wm13Q-MngsdUQ  zztOG2cKm87I6Iw_tleZsQ      4.921060
#
# [985732 rows x 3 columns]

# %%
train_data, test_data = train_test_split(user_business, test_size=0.2, random_state=42)

user_business = train_data.copy()

# %%
for user_id, group in user_business.groupby('user_id'):
    print(group)
    break
# Out:
#                        user_id             business_id  stars_review
# 701644  ---UgP94gokyCDuB5zUssA  hKr-RKMVpj3gRkSWcjg3Zw      2.903193
# 785599  ---UgP94gokyCDuB5zUssA  mtrXz0nBaMO-ijQewaLG6A      3.897722
# 376009  ---UgP94gokyCDuB5zUssA  NAMen7YzwlYDs_5ECMnuYQ      4.909942
# 779732  ---UgP94gokyCDuB5zUssA  mV1UTSvEm-mhaPGFiIGhhQ      0.970888

# %%
cluster_id = user_cluster.get('---UgP94gokyCDuB5zUssA')
for business_id in cluster_items.get(cluster_id):
    print(business_id)
    print(cluster_business_avg_dict.get((cluster_id, business_id))
)
    break
# Out:
# FXsu9JqnLl2D0wqeQP4QKw
# 4.908063605566664

# %%
# Initialize a list for augmented interactions
df_augmented_interactions = pd.DataFrame(
    columns=['user_id', 'business_id', 'stars_review']
)
# Process each user
for user_id, group in user_business.groupby('user_id'):
    user_review_count = review_counts.get(user_id, 0)  # Default to 0 if user not in df_reviewc
    if user_review_count >= median_review_count:
        # Users with sufficient reviews: keep original interactions
        for _, row in group.iterrows():
            df_augmented_interactions = pd.concat(
                [df_augmented_interactions, pd.DataFrame(
                    {'user_id': [user_id], 'business_id': [row['business_id']], 'stars_review': [row['stars_review']]}
                )],
                ignore_index=True
            )
    else:
        # Users with fewer reviews: check cluster and augment
        user_cluster_id = user_cluster.get(user_id)
        if user_cluster_id is not None:  # If user has a cluster
            # Get the cluster's businesses as a DataFrame
            cluster_data = cluster_items.get(user_cluster_id)
            if cluster_data is not None:
                # Get the user's interacted businesses
                user_interacted_businesses = set(group['business_id'])
                # Add cluster businesses not yet reviewed with cluster-specific average rating
                for business_id in cluster_data:
                    if business_id not in user_interacted_businesses:
                        # Look up the cluster-specific average rating
                        avg_rating = cluster_business_avg_dict.get((user_cluster_id, business_id))
                        if avg_rating is not None:
                            df_augmented_interactions = pd.concat(
                                [df_augmented_interactions, pd.DataFrame(
                                    {'user_id': [user_id], 'business_id': [business_id], 'stars_review': [avg_rating]}
                                )],
                                ignore_index=True
                            )
            # Keep the user's original interactions
            for _, row in group.iterrows():
                df_augmented_interactions = pd.concat(
                    [df_augmented_interactions, pd.DataFrame(
                        {'user_id': [user_id], 'business_id': [row['business_id']], 'stars_review': [row['stars_review']]}
                    )],
                    ignore_index=True
                )
# Out:
# C:\Users\cathy\AppData\Local\Temp\ipykernel_27948\302208502.py:11: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_augmented_interactions = pd.concat(

# %%
user_business = df_augmented_interactions.copy()

# %%
user_business
# Out:
#                        user_id             business_id  stars_review
# 0       ---UgP94gokyCDuB5zUssA  hKr-RKMVpj3gRkSWcjg3Zw      2.903193
# 1       ---UgP94gokyCDuB5zUssA  mtrXz0nBaMO-ijQewaLG6A      3.897722
# 2       ---UgP94gokyCDuB5zUssA  NAMen7YzwlYDs_5ECMnuYQ      4.909942
# 3       ---UgP94gokyCDuB5zUssA  mV1UTSvEm-mhaPGFiIGhhQ      0.970888
# 4       --17Db1K-KujRuN7hY9Z0Q  3fpAmsSuEFNF29UUPpgwlw      4.883035
# ...                        ...                     ...           ...
# 734413  zztkCqqgR6VntYbqio4UTQ  dG1pPWaVoIHWMIChKjfolg      4.895180
# 734414  zztkCqqgR6VntYbqio4UTQ  BmKCJsV_payJ5ANqC7i85g      4.888912
# 734415  zztkCqqgR6VntYbqio4UTQ  yGKeP2m3RefZY-kFqjTNGQ      3.909339
# 734416  zztkCqqgR6VntYbqio4UTQ  LGYIhGqbYakMMdsn_GCzJg      4.899462
# 734417  zztkCqqgR6VntYbqio4UTQ  DgLwvHu6wNt2SrFvE5xxHQ      4.898337
#
# [734418 rows x 3 columns]

# %%
# Map user_id and business_id to numerical indices
user_business['user_idx'] = user_business['user_id'].map(user_mapping)
user_business['business_idx'] = user_business['business_id'].map(business_mapping)

# Creating the sparse user-item interaction matrix using weighted_stars
user_item_sparse = csr_matrix(
    (user_business['stars_review'], (user_business['user_idx'], user_business['business_idx'])),
    shape=(len(user_mapping), len(business_mapping))
)

# Replace NaN values in the sparse matrix
user_item_sparse.data = np.nan_to_num(user_item_sparse.data)

# %%
def sparse_cosine_similarity_topn(A, top_n, threshold=0):
    # A is the sparse matrix (user-item matrix)
    # ntop is the number of top similar items you want
    # lower_bound is the minimum similarity score to consider
    
    # Compute the top N cosine similarities in a sparse format
    C = sp_matmul_topn(A.T, A.T, top_n=top_n, threshold=threshold, n_threads=4, sort=True)

    return C

# %%
# Compute item similarity
item_similarity_sparse = sparse_cosine_similarity_topn(user_item_sparse, top_n=50, threshold=0.01)

# %%
def optimize_db(conn):
    """Apply SQLite performance optimizations."""
    cursor = conn.cursor()
    cursor.executescript('''
        PRAGMA synchronous = OFF;
        PRAGMA journal_mode = MEMORY;
        PRAGMA temp_store = MEMORY;
        PRAGMA cache_size = 1000000;
    ''')
    conn.commit()


def insert_user_item(user_business, conn, batch_size=50000):
    """Optimized batch insert for user-item interactions."""
    cursor = conn.cursor()
    cursor.execute('BEGIN TRANSACTION')

    total_records = len(user_business)
    data = user_business[['user_id', 'business_id', 'stars_review']].values.tolist()

    for i in range(0, total_records, batch_size):
        batch = data[i:i + batch_size]
        cursor.executemany('''INSERT OR IGNORE INTO user_item_index (user_id, business_id, stars_review)
                              VALUES (?, ?, ?)''', batch)

        if i % (batch_size * 5) == 0:  # Commit every 5 batches
            conn.commit()
            print(f"Inserted {i + len(batch)} / {total_records} user-item records.")

    conn.commit()  # Final commit
    print(f"Total {total_records} user-item records inserted.")


def insert_item_vectors(item_similarity_sparse, business_mapping, conn, batch_size=5000, progress_interval=50000):
    """Optimized batch insert for item similarity vectors."""
    cursor = conn.cursor()
    cursor.execute('BEGIN TRANSACTION')

    total_inserted = 0
    batch = []
    business_keys = list(business_mapping.keys())  # Convert keys to list for faster indexing

    for row_idx in range(item_similarity_sparse.shape[0]):
        row_vector = item_similarity_sparse.getrow(row_idx)
        row_indices = row_vector.indices
        row_data = row_vector.data

        serialized_row = pickle.dumps((row_indices, row_data))
        item_id = business_keys[row_idx]  # Faster lookup

        batch.append((item_id, serialized_row))

        if len(batch) >= batch_size:
            cursor.executemany('''INSERT OR REPLACE INTO item_item_similarity (item_id, similarity_vector)
                                  VALUES (?, ?)''', batch)
            total_inserted += len(batch)

            if total_inserted % progress_interval == 0:
                print(f"Inserted {total_inserted} item vectors...")

            batch = []

    if batch:  # Insert remaining records
        cursor.executemany('''INSERT OR REPLACE INTO item_item_similarity (item_id, similarity_vector)
                              VALUES (?, ?)''', batch)
        total_inserted += len(batch)

    conn.commit()
    print(f"Total {total_inserted} item vectors inserted.")


def insert_mappings(business_mapping, conn, batch_size=50000):
    """Optimized batch insert for business mappings."""
    cursor = conn.cursor()
    cursor.execute('BEGIN TRANSACTION')

    data = list(business_mapping.items())
    total_records = len(data)

    for i in range(0, total_records, batch_size):
        batch = data[i:i + batch_size]
        cursor.executemany('''INSERT OR REPLACE INTO business_mapping (business_id, business_idx)
                              VALUES (?, ?)''', batch)

        if i % (batch_size * 5) == 0:  # Commit every 5 batches
            conn.commit()
            print(f"Inserted {i + len(batch)} / {total_records} business mappings.")

    conn.commit()
    print(f"Total {total_records} business mappings inserted.")

# %%
# Connect to SQLite (this will create a file-based database)
db_path = './yelp_ItemCF.db'
conn = sqlite3.connect(db_path)
cursor = conn.cursor()
optimize_db(conn)

# Create tables for user-item and item-item indexes
cursor.execute('''CREATE TABLE IF NOT EXISTS user_item_index (
    user_id TEXT,
    business_id TEXT,
    stars_review REAL,
    PRIMARY KEY (user_id, business_id)
)''')

cursor.execute('''CREATE INDEX IF NOT EXISTS idx_user_item ON user_item_index(user_id, business_id)''')

cursor.execute('''CREATE TABLE IF NOT EXISTS item_item_similarity (
    item_id TEXT PRIMARY KEY,
    similarity_vector BLOB
)''')

cursor.execute('''CREATE INDEX IF NOT EXISTS idx_item_similarity ON item_item_similarity(item_id)''')

# cursor.execute('''CREATE TABLE IF NOT EXISTS user_mapping (
#     user_id TEXT PRIMARY KEY,
#     user_idx INTEGER
# )''')

cursor.execute('''CREATE TABLE IF NOT EXISTS business_mapping (
    business_id TEXT PRIMARY KEY,
    business_idx INTEGER
)''')


# Commit the changes
conn.commit()

# %%
insert_user_item(user_business, conn)
insert_item_vectors(item_similarity_sparse, business_mapping, conn)
insert_mappings(business_mapping, conn)
# Out:
# Inserted 50000 / 734418 user-item records.
# Inserted 300000 / 734418 user-item records.
# Inserted 550000 / 734418 user-item records.
# Total 734418 user-item records inserted.
# Inserted 50000 item vectors...
# Total 78059 item vectors inserted.
# Inserted 50000 / 78059 business mappings.
# Total 78059 business mappings inserted.

# %%
# Close the connection when done
conn.close()

# %%
print("Database operations completed successfully.")
